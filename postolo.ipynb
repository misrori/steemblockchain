# %%
import requests
import json
adat = requests.post('http://127.0.0.1:54321/get_all_tr', json={"name": 'admin'})
adat
# Out:
# <Response [200]>

# %%
k= adat.json()

# %%
k
# Out:
# {'adat': [[0,
#    {'block': 1092,
#     'op': ['pow',
#      {'block_id': '000004433bd4602cf5f74dbb564183837df9cef8',
#       'nonce': 82,
#       'props': {'account_creation_fee': {'amount': '100000',
#         'nai': '@@000000021',
#         'precision': 3},
#        'maximum_block_size': 131072,
#        'sbd_interest_rate': 1000},
#       'work': {'input': '59b009f89477919f95914151cef06f28bf344dd6fb7670aca1c1f4323c80446b',
#        'signature': '1f3f83209097efcd01b7d6f27ce726164323d503d6fcf4d55bfb7cb3032796f6766738b36062b5850d69447fdf9c091cbc70825df5eeacc4710a0b11ffdbf0912a',
#        'work': '0b62f4837801cd857f01d6a541faeb13d6bb95f1c36c6b4b14a47df632aa6c92',
#        'worker': 'STM65wH1LZ7BfSHcK69SShnqCAH5xdoSZpGkUjmzHJ5GCuxEK9V5G'},
#       'worker_account': 'admin'}],
#     'op_in_trx': 0,
#     'timestamp': '2016-03-24T17:00:03',
#     'trx_id': 'ef73d8fadf17e2590c6d96efc1ca868edd7dd613',
#     'trx_in_block': 0,
#     'virtual_op': 0}],
#   [1,
#    {'block': 1092,
# ...
