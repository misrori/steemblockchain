# %%
from steem import Steem
import pandas as pd
s = Steem()


def get_number_of_transaction(name):

    t = s.steemd.get_account_history(name,index_from=-1, limit=1 )

    return(t[-1][0]+1)

def get_all_tr(name):
    osszes=[]
    szamlalo=10000

    while True:
        print(szamlalo)
        t = s.steemd.get_account_history(name, index_from=szamlalo, limit=10000)
        if osszes:
            utolso = osszes[-1][0]
        else:
            utolso=t[-1][0]
        
        if(t[-1][0]!=szamlalo):
            kell_meg = t[-1][0]-utolso
            osszes.extend(t[-kell_meg:])
            break

        osszes.extend(t[0:-1])
        szamlalo+=10000
    return(osszes)

# %%
osszes = get_all_tr('ned')
# Out:
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000

# %%
len(osszes)
# Out:
# 86622

# %%
osszes[0:1000]
# Out:
# [[0,
#   {'block': 198206,
#    'op': ['account_create',
#     {'active': {'account_auths': [],
#       'key_auths': [['STM8hiqhFWFSgonq3CCqZWEV4qQEEcnVNCoSkGkagnwEraPnWKaAR',
#         1]],
#       'weight_threshold': 1},
#      'creator': 'steemit',
#      'fee': '100.000 STEEM',
#      'json_metadata': '',
#      'memo_key': 'STM5Ccjqmgmpcir4Bn1uNMbiUi8MytuYz3aBTtXineAXu3kHY9ka8',
#      'new_account_name': 'ned',
#      'owner': {'account_auths': [],
#       'key_auths': [['STM6du8wJhCYQCXCWLFXPjT6Xx6FZj1AhXADizzk2t317AXao1cvp',
#         1]],
#       'weight_threshold': 1},
#      'posting': {'account_auths': [],
#       'key_auths': [['STM83RGb5BZWTqpr8J5gTA9adnYX5aWjQcuvfA4k5zi5qEsNkoHb5',
#         1]],
#       'weight_threshold': 1}}],
#    'op_in_trx': 0,
#    'timestamp': '2016-03-31T14:21:45',
#    'trx_id': '7f08e0025d0ae60aaf099078460a9d024387a44c',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [1,
#   {'block': 200578,
#    'op': ['transfer_to_vesting',
#     {'amount': '9264.000 STEEM', 'from': 'steemit', 'to': 'ned'}],
#    'op_in_trx': 0,
#    'timestamp': '2016-03-31T16:20:21',
#    'trx_id': '34e8ed73914b9d4516599fa248e78a77e3384724',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [2,
#   {'block': 629136,
#    'op': ['vote',
#     {'author': 'dele-puppy',
#      'permlink': 'dele-puppy-witness-post',
#      'voter': 'ned',
#      'weight': -100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-15T21:54:51',
#    'trx_id': '0177ca1f3f810885d8b8076fc8b12b57971cb292',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [3,
#   {'block': 629491,
#    'op': ['transfer',
#     {'amount': '1.000 STEEM',
#      'from': 'dantheman',
#      'memo': 'thanks bro!',
#      'to': 'ned'}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-15T22:13:03',
#    'trx_id': '4e87da55babbf9d1dd080b50c715022558a26fd0',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [4,
#   {'block': 629504,
#    'op': ['transfer',
#     {'amount': '1.000 STEEM',
#      'from': 'dantheman',
#      'memo': 'another demo',
#      'to': 'ned'}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-15T22:13:42',
#    'trx_id': 'e2dc64bb5d05a3f414ef348ffb58ea81b29f1816',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [5,
#   {'block': 651824,
#    'op': ['vote',
#     {'author': 'xeroc',
#      'permlink': 'steem-blockchain-data-structure',
#      'voter': 'ned',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T17:00:00',
#    'trx_id': '04958be260c3565e63817a78a10c420f9cca97f9',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [6,
#   {'block': 651830,
#    'op': ['vote',
#     {'author': 'steem-id',
#      'permlink': 'steem-introduction',
#      'voter': 'ned',
#      'weight': -100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T17:00:18',
#    'trx_id': '0bce90666f3056cd1974b6510603e5ac8f062c75',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [7,
#   {'block': 651835,
#    'op': ['vote',
#     {'author': 'datasecuritynode',
#      'permlink': 'datasecuritynode-witness-post',
#      'voter': 'ned',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T17:00:33',
#    'trx_id': '86ffb461f03ad9a1676a5e3015a8b6a44d760359',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [8,
#   {'block': 652062,
#    'op': ['vote',
#     {'author': 'abit',
#      'permlink': 'anti-spam',
#      'voter': 'ned',
#      'weight': -100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T17:11:54',
#    'trx_id': '4c100f4680c1a785d171c1d4a9ef7e39b954e2f3',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [9,
#   {'block': 652065,
#    'op': ['vote',
#     {'author': 'xeroc',
#      'permlink': 'python-steem-0-1',
#      'voter': 'ned',
#      'weight': -100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T17:12:03',
#    'trx_id': '44b082f473948398444798250d4af83db787ddf4',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [10,
#   {'block': 652067,
#    'op': ['vote',
#     {'author': 'roadscape',
#      'permlink': 'steem-explorer',
#      'voter': 'ned',
#      'weight': -100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T17:12:09',
#    'trx_id': '9b099f695a5ed0f7b4d5809644bad37d5bfdb54a',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [11,
#   {'block': 652069,
#    'op': ['vote',
#     {'author': 'bastiat',
#      'permlink': 'bastiat-quote-government',
#      'voter': 'ned',
#      'weight': -100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T17:12:15',
#    'trx_id': '82eca534fec93b4da876194a97364e934181b3b3',
#    'trx_in_block': 1,
#    'virtual_op': 0}],
#  [12,
#   {'block': 652071,
#    'op': ['vote',
#     {'author': 'xeroc',
#      'permlink': 'how-to-monitor-an-account-on-steem',
#      'voter': 'ned',
#      'weight': -100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T17:12:21',
#    'trx_id': '123d920327713336f05bddd1ba88a80405c6dd02',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [13,
#   {'block': 652072,
#    'op': ['vote',
#     {'author': 'val',
#      'permlink': 'urls-scheme',
#      'voter': 'ned',
#      'weight': -100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T17:12:24',
#    'trx_id': '926b99243eab5eccf5105794efc9a187888aadd0',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [14,
#   {'block': 652074,
#    'op': ['vote',
#     {'author': 'dele-puppy',
#      'permlink': 'knaves-fools-and-do-nothings',
#      'voter': 'ned',
#      'weight': -100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T17:12:30',
#    'trx_id': 'ae010fdc0d552447bb03908305a6fb7127722753',
#    'trx_in_block': 1,
#    'virtual_op': 0}],
#  [15,
#   {'block': 652079,
#    'op': ['vote',
#     {'author': 'steempty',
#      'permlink': 'steempty-witness-post',
#      'voter': 'ned',
#      'weight': -100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T17:12:45',
#    'trx_id': '54ee5df668be3cc1a36d1900dcabe13267784fac',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [16,
#   {'block': 652081,
#    'op': ['vote',
#     {'author': 'lafona',
#      'permlink': 'lafona-witness-post',
#      'voter': 'ned',
#      'weight': -100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T17:12:51',
#    'trx_id': '10f1a4b97343640352c0205676b8d8902022e65b',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [17,
#   {'block': 652082,
#    'op': ['vote',
#     {'author': 'steemit',
#      'permlink': 'firstpost',
#      'voter': 'ned',
#      'weight': -100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T17:12:54',
#    'trx_id': 'dba5a744de319a968692c47fda7a86ff7db91803',
#    'trx_in_block': 1,
#    'virtual_op': 0}],
#  [18,
#   {'block': 652084,
#    'op': ['vote',
#     {'author': 'wackou',
#      'permlink': 'wackou-witness-post',
#      'voter': 'ned',
#      'weight': -100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T17:13:00',
#    'trx_id': '3cb706f5bff0cd4f9a1d1b7dd4ea60c347ac3db0',
#    'trx_in_block': 1,
#    'virtual_op': 0}],
#  [19,
#   {'block': 652085,
#    'op': ['vote',
#     {'author': 'fmooo',
#      'permlink': 'steemd-docker',
#      'voter': 'ned',
#      'weight': -100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T17:13:03',
#    'trx_id': '24a02f7293a34ab98644d3f878944adc18c5110f',
#    'trx_in_block': 1,
#    'virtual_op': 0}],
#  [20,
#   {'block': 652087,
#    'op': ['vote',
#     {'author': 'cyrano.witness',
#      'permlink': 'cyrano-witness-post',
#      'voter': 'ned',
#      'weight': -100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T17:13:09',
#    'trx_id': 'a4586e4d12484502aade400c15deeb3e3703d5bd',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [21,
#   {'block': 652091,
#    'op': ['vote',
#     {'author': 'abit',
#      'permlink': 'abit-witness-post',
#      'voter': 'ned',
#      'weight': -100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T17:13:21',
#    'trx_id': 'b5f50cdcd46447610914e85f4390954f5132717b',
#    'trx_in_block': 1,
#    'virtual_op': 0}],
#  [22,
#   {'block': 652095,
#    'op': ['vote',
#     {'author': 'hello', 'permlink': 'hello', 'voter': 'ned', 'weight': -100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T17:13:33',
#    'trx_id': '88faec7e06dd85f853aafcd793eb1c459c2b9a74',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [23,
#   {'block': 652097,
#    'op': ['vote',
#     {'author': 'xeldal',
#      'permlink': 'xeldal-witness-post',
#      'voter': 'ned',
#      'weight': -100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T17:13:39',
#    'trx_id': 'a94b53888cb5f5db8855b58874ebc1850430efad',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [24,
#   {'block': 652108,
#    'op': ['vote',
#     {'author': 'red',
#      'permlink': 'inspirational-quote-of-the-day',
#      'voter': 'ned',
#      'weight': -100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T17:14:12',
#    'trx_id': '0a5767cace2fbd879ad539a031a17d5098ba2d90',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [25,
#   {'block': 652110,
#    'op': ['vote',
#     {'author': 'nextgencrypto',
#      'permlink': 'basic-mining-instructions--ubuntu-15',
#      'voter': 'ned',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T17:14:18',
#    'trx_id': 'd00a48424076f6687809b57c2ec29100bc6039d6',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [26,
#   {'block': 652118,
#    'op': ['vote',
#     {'author': 'red',
#      'permlink': 'way-too-disturbing-to-be-real',
#      'voter': 'ned',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T17:14:42',
#    'trx_id': '3908c4dacaaa547d527ad26d6b24bdb58cfa4a8a',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [27,
#   {'block': 652123,
#    'op': ['vote',
#     {'author': 'red', 'permlink': 'laughable', 'voter': 'ned', 'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T17:14:57',
#    'trx_id': 'e3eb8bb20faae18ca1b12315de6440b385ad0697',
#    'trx_in_block': 1,
#    'virtual_op': 0}],
#  [28,
#   {'block': 652174,
#    'op': ['vote',
#     {'author': 'proskynneo',
#      'permlink': 'steemit-firstpost-1',
#      'voter': 'ned',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T17:17:30',
#    'trx_id': 'e3d91b09a06fc38f23b604cd106ea846d8315495',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [29,
#   {'block': 652551,
#    'op': ['comment',
#     {'author': 'ned',
#      'body': '"steemians" +1',
#      'json_metadata': '{}',
#      'parent_author': 'lafona',
#      'parent_permlink': 'lafona-witness-post',
#      'permlink': 're-lafona-lafona-witness-post-20160416t173622565z',
#      'title': ''}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T17:36:21',
#    'trx_id': 'b213c89f9ddf067d557814efac85f44d67360aa1',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [30,
#   {'block': 652554,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 're-lafona-lafona-witness-post-20160416t173622565z',
#      'voter': 'ned',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T17:36:30',
#    'trx_id': '36a17b14da678801e1c1005cb7a74f802ba56056',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [31,
#   {'block': 652569,
#    'op': ['vote',
#     {'author': 'justin', 'permlink': 'test', 'voter': 'ned', 'weight': -100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T17:37:15',
#    'trx_id': 'a54e148b8037bcd1bdd91f322e569eaddfc82941',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [32,
#   {'block': 652571,
#    'op': ['vote',
#     {'author': 'ice', 'permlink': 'taiwan', 'voter': 'ned', 'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T17:37:21',
#    'trx_id': 'b6e5e6b55af87d889d97c93bbaad64bad669be51',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [33,
#   {'block': 655585,
#    'op': ['vote',
#     {'author': 'red',
#      'permlink': 'fast-reply',
#      'voter': 'ned',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T20:09:42',
#    'trx_id': '80b80c8ccc00ea5ce8582c1a5ed4082c98d384ad',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [34,
#   {'block': 656017,
#    'op': ['comment',
#     {'author': 'ned',
#      'body': 'http://s24.postimg.org/5wlxze75x/STEEM_logo_color_typo_pt.png',
#      'json_metadata': '{}',
#      'parent_author': '',
#      'parent_permlink': 'steem',
#      'permlink': 'one-small-step-for-steem-one-giant-leap-for-steemkind',
#      'title': 'one small step for steem, one giant leap for steemkind'}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T20:31:18',
#    'trx_id': 'e6a8a0e1d10180ae9dad010b91ba2dfe00cf22de',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [35,
#   {'block': 656021,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 'one-small-step-for-steem-one-giant-leap-for-steemkind',
#      'voter': 'ned',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-16T20:31:30',
#    'trx_id': 'e6b770c2266dbba1b881dda4ee630ff1d8e64cc8',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [36,
#   {'block': 667728,
#    'op': ['comment',
#     {'author': 'steemian',
#      'body': '![steem logo](http://s24.postimg.org/5wlxze75x/STEEM_logo_color_typo_pt.png "Steem Logo")',
#      'json_metadata': '{}',
#      'parent_author': 'ned',
#      'parent_permlink': 'one-small-step-for-steem-one-giant-leap-for-steemkind',
#      'permlink': 're-ned-one-small-step-for-steem-one-giant-leap-for-steemkind',
#      'title': ''}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-17T06:25:54',
#    'trx_id': 'd0d68beea178c22bdf00c6d6b76b8065f613bbaa',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [37,
#   {'block': 678346,
#    'op': ['comment',
#     {'author': 'ned',
#      'body': 'The content will remain in the Steem Chain regardless of IP ownership.\n\nHowever, Steemit is a privately managed site .. IP owners can ask us to not show content .. they can ask the poster for retribution .. or better, they can start to post their own content directly :)',
#      'json_metadata': '{}',
#      'parent_author': 'cyrano',
#      'parent_permlink': 'how-to-deal-with-stolen-content',
#      'permlink': 're-cyrano-how-to-deal-with-stolen-content-20160417t153906482z',
#      'title': ''}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-17T15:39:06',
#    'trx_id': '44b8d0d7b101f3556f3699021c753057e24f1a88',
#    'trx_in_block': 1,
#    'virtual_op': 0}],
#  [38,
#   {'block': 678351,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 're-cyrano-how-to-deal-with-stolen-content-20160417t153906482z',
#      'voter': 'ned',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-17T15:39:21',
#    'trx_id': '3234a426c6298bebbdbe02d1c93c9754c7eac30f',
#    'trx_in_block': 1,
#    'virtual_op': 0}],
#  [39,
#   {'block': 678701,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 're-cyrano-how-to-deal-with-stolen-content-20160417t153906482z',
#      'voter': 'satoshi',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-17T15:57:15',
#    'trx_id': '2ddeb3d91eda335e720cec94892dbf2506c170fd',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [40,
#   {'block': 679416,
#    'op': ['vote',
#     {'author': 'jabbasteem',
#      'permlink': 'second-try',
#      'voter': 'ned',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-17T16:33:51',
#    'trx_id': '7495ce07de2430a636c4a360e080b3985e795939',
#    'trx_in_block': 1,
#    'virtual_op': 0}],
#  [41,
#   {'block': 679825,
#    'op': ['vote',
#     {'author': 'cyrano',
#      'permlink': 'how-to-deal-with-stolen-content',
#      'voter': 'ned',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-17T16:55:21',
#    'trx_id': 'd72387b88ff187a3d9039f1a086a0776b63e33c3',
#    'trx_in_block': 1,
#    'virtual_op': 0}],
#  [42,
#   {'block': 679840,
#    'op': ['vote',
#     {'author': 'nextgencrypto',
#      'permlink': 'steem-is-now-trading-on-bittrex-exchange',
#      'voter': 'ned',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-17T16:56:12',
#    'trx_id': '7d96d2bd78bc983c831acef6cf2edb2626cf95ed',
#    'trx_in_block': 1,
#    'virtual_op': 0}],
#  [43,
#   {'block': 679842,
#    'op': ['vote',
#     {'author': 'justin',
#      'permlink': 're-nextgencrypto-steem-is-now-trading-on-bittrex-exchange-20160417t031534657z',
#      'voter': 'ned',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-17T16:56:18',
#    'trx_id': '7e3de077b7b83c6e10d2152a98fd3d1ea17d4b35',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [44,
#   {'block': 679856,
#    'op': ['vote',
#     {'author': 'mileycyrus',
#      'permlink': 'miley-liam',
#      'voter': 'ned',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-17T16:57:00',
#    'trx_id': 'c19dd62f8fe5dfa6255666412088d9b86d06c1d1',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [45,
#   {'block': 684754,
#    'op': ['comment',
#     {'author': 'cyrano',
#      'body': "Thanks for your reply.\n\n> The content will remain in the Steem Chain regardless of IP ownership.\nYes, that is the problem. Have your considered this problem, or don't you think this is a problem at all?\n\n> However, Steemit is a privately managed site\nMy question was not about steemit.com - that's a different issue obviously. My question was about the risks that node operators are facing. Have you evaluated the possible legal risks? Don't you think lawsuits against steem node operators might be harmful to the network as a whole? I mean, every witness has to run a node, obviously.\n\nI think this is really a weak point in steem. I'm sure there *are* solutions. Freenet for example has all of its content encrypted, which means that freenet node operators can always plausibly deny knowledge of the content they are serving. (<https://freenetproject.org/documentation.html#understand>)",
#      'json_metadata': '',
#      'parent_author': 'ned',
#      'parent_permlink': 're-cyrano-how-to-deal-with-stolen-content-20160417t153906482z',
#      'permlink': 're2-how-to-deal-with-stolen-content',
#      'title': ''}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-17T21:07:00',
#    'trx_id': '298d50a679ee9d92a8c666bb79a0a3896d91b0d7',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [46,
#   {'block': 684785,
#    'op': ['comment',
#     {'author': 'cyrano',
#      'body': "Thanks for your reply.\n\n> The content will remain in the Steem Chain regardless of IP ownership.\n\nYes, that is the problem. Have your considered this problem, or don't you think this is a problem at all?\n\n> However, Steemit is a privately managed site\n\nMy question was not about steemit.com - that's a different issue obviously. My question was about the risks that node operators are facing. Have you evaluated the possible legal risks? Don't you think lawsuits against steem node operators might be harmful to the network as a whole? I mean, every witness has to run a node, obviously.\n\nI think this is really a weak point in steem. I'm sure there *are* solutions. Freenet for example has all of its content encrypted, which means that freenet node operators can always plausibly deny knowledge of the content they are serving. (<https://freenetproject.org/documentation.html#understand>)",
#      'json_metadata': '',
#      'parent_author': 'ned',
#      'parent_permlink': 're-cyrano-how-to-deal-with-stolen-content-20160417t153906482z',
#      'permlink': 're2-how-to-deal-with-stolen-content',
#      'title': ''}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-17T21:08:33',
#    'trx_id': '0f8f24059f92664f299dd3f0bddd8e30b41b9383',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [47,
#   {'block': 706211,
#    'op': ['vote',
#     {'author': 'mileycyrus',
#      'permlink': 'miley-girls-lunch',
#      'voter': 'ned',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-18T15:25:21',
#    'trx_id': '28c4bb1cf21d717108d4feb613e7f729cfa4beff',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [48,
#   {'block': 706213,
#    'op': ['vote',
#     {'author': 'taylorswift',
#      'permlink': 'taylor-swift-danced-at-coachella-and-attended-a-friends-wedding-1200-miles-away-in-one',
#      'voter': 'ned',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-18T15:25:30',
#    'trx_id': '1898c8860a4e241704e3261d867323fed8ccf9d8',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [49,
#   {'block': 706216,
#    'op': ['vote',
#     {'author': 'mileycyrus',
#      'permlink': 'miley-mystery-man',
#      'voter': 'ned',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-18T15:25:39',
#    'trx_id': '5742dc2c3c0412358079fb296c6228ee153f1105',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [50,
#   {'block': 706217,
#    'op': ['vote',
#     {'author': 'samupaha',
#      'permlink': 'steem-is-becoming-alive-lets-celebrate-with-yodeling',
#      'voter': 'ned',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-18T15:25:42',
#    'trx_id': 'e6fc41f1ceccc2e24d8d20d7b9d2fcc6d6fa5433',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [51,
#   {'block': 706226,
#    'op': ['vote',
#     {'author': 'doom',
#      'permlink': 'blocktrades-dev-uses-privileged-possition-to-dump-steem-then-takes-vacation-',
#      'voter': 'ned',
#      'weight': -100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-18T15:26:09',
#    'trx_id': 'fb596849e6d21aeb4ca27e226d3b137eacf81110',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [52,
#   {'block': 706238,
#    'op': ['vote',
#     {'author': 'pharesim',
#      'permlink': 're-doom-blocktrades-dev-uses-privileged-possition-to-dump-steem-then-takes-vacation-',
#      'voter': 'ned',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-18T15:26:45',
#    'trx_id': '32f6bf6179d6159a9bc21200a1787e1c24e747bc',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [53,
#   {'block': 712835,
#    'op': ['vote',
#     {'author': 'dantheman',
#      'permlink': 'introduction-to-steem-dollars-sbd',
#      'voter': 'ned',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-18T21:12:30',
#    'trx_id': '10a2e32cfddbdc67e4653018fbd69550ee66f46e',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [54,
#   {'block': 712862,
#    'op': ['vote',
#     {'author': 'doom',
#      'permlink': 'bittrex-first-to-market-offers-steem-trade-depositwithdraw-is-live',
#      'voter': 'ned',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-18T21:13:54',
#    'trx_id': 'aa36324920259773ca4ded854c6c79b5912c5697',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [55,
#   {'block': 718211,
#    'op': ['comment',
#     {'author': 'ned',
#      'body': "[PREDICTION] How Steem's Voters Will Perceive Post Value: \n\n1. Original content > copied\n2. Dialogue > monologue \n3. Identity > pseudo anonymity > anonymity \n4. Video > picture > text\n5. English > non-English\n6. SFW > NSFW\n7. Ideas > events > people\n8. Postitive > negative\n9. New info > info found elsewhere\n\n\n(check back 1 year from now)",
#      'json_metadata': '{}',
#      'parent_author': '',
#      'parent_permlink': 'steem',
#      'permlink': 'prediction-voter-perceived-value',
#      'title': '[PREDICTION] Voter Perceived Value'}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-19T01:46:45',
#    'trx_id': 'b71685437b7d1839775c0fce2f292052c52209c4',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [56,
#   {'block': 718231,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 'prediction-voter-perceived-value',
#      'voter': 'ned',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-19T01:47:48',
#    'trx_id': '0404684575abbee1555584a7e0b8ab3956ba0643',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [57,
#   {'block': 719245,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 'prediction-voter-perceived-value',
#      'voter': 'xeldal',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-19T02:40:54',
#    'trx_id': '9d9ca0064244c6645940e7f31357405f8593a406',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [58,
#   {'block': 736383,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 'prediction-voter-perceived-value',
#      'voter': 'samupaha',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-19T17:19:57',
#    'trx_id': '8cd6d6150d3c27d53253aa9c5e148c2d430e0bdd',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [59,
#   {'block': 740236,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 'prediction-voter-perceived-value',
#      'voter': 'fmooo',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-19T20:45:03',
#    'trx_id': '35c1e188ed962e0434215336d78d824140955414',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [60,
#   {'block': 741133,
#    'op': ['vote',
#     {'author': 'dantheman',
#      'permlink': 'how-to-calculate-the-market-capitalization-of-steem',
#      'voter': 'ned',
#      'weight': -100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-19T21:32:03',
#    'trx_id': '35188ccbf2ee80a18153e5c115662a908734a9db',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [61,
#   {'block': 759037,
#    'op': ['vote',
#     {'author': 'clayop',
#      'permlink': 'steem-miner-setup-in-ubuntu-15',
#      'voter': 'ned',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-20T12:35:57',
#    'trx_id': '3a947989477a586378655459f68fad8f3da4b6f9',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [62,
#   {'block': 759045,
#    'op': ['vote',
#     {'author': 'pharesim',
#      'permlink': 'show-your-pets',
#      'voter': 'ned',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-20T12:36:21',
#    'trx_id': '9881e45a80d137a22a8a507efb614d1aab262158',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [63,
#   {'block': 759056,
#    'op': ['vote',
#     {'author': 'steemed',
#      'permlink': 'rich-list-link',
#      'voter': 'ned',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-20T12:36:54',
#    'trx_id': 'e7d6170a0f82db19518f73cdd458def9a1fe029b',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [64,
#   {'block': 768940,
#    'op': ['vote',
#     {'author': 'steemychicken1',
#      'permlink': 're-steemed-change-posting-key-20160420t211005101z',
#      'voter': 'ned',
#      'weight': 100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-20T21:19:51',
#    'trx_id': 'b01b11d41bf0ea6bbc4ff82f851431f78b8c27e2',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [65,
#   {'block': 772357,
#    'op': ['vote',
#     {'author': 'roadscape',
#      'permlink': 'witness-roadscape',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-21T00:14:33',
#    'trx_id': 'd987533ae87192749d62180faed75fb8c014b1d1',
#    'trx_in_block': 1,
#    'virtual_op': 0}],
#  [66,
#   {'block': 772369,
#    'op': ['vote',
#     {'author': 'pharesim',
#      'permlink': 'witness-post',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-21T00:15:18',
#    'trx_id': 'd33eefae96c22942f5f7a559e9bd54a7e3905bde',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [67,
#   {'block': 772374,
#    'op': ['vote',
#     {'author': 'justin',
#      'permlink': 'steem-is-now-listed-on-coinmarketcap',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-21T00:15:33',
#    'trx_id': 'cea61ca8043d68af749cc311f6f375b7e6799f89',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [68,
#   {'block': 772379,
#    'op': ['vote',
#     {'author': 'kushed',
#      'permlink': 'steem-steemit',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-21T00:15:48',
#    'trx_id': 'bf46b7b47fd3c77649b5b1d59f8f7989d4317efd',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [69,
#   {'block': 772498,
#    'op': ['vote',
#     {'author': 'nextgencrypto',
#      'permlink': 'steem-price-speculation',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-21T00:22:30',
#    'trx_id': '36f03d4a10d88f2dd1b77e3a32faee4deb4d1e5f',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [70,
#   {'block': 772504,
#    'op': ['vote',
#     {'author': 'nextgencrypto',
#      'permlink': 're-samupaha-re-nextgencrypto-steem-price-speculation-20160419t053137009z-20160419t063916480z',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-21T00:22:51',
#    'trx_id': '4dbe8aeb5fc0a775bddd9e4736084cf77d23ca32',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [71,
#   {'block': 786822,
#    'op': ['vote',
#     {'author': 'clayop',
#      'permlink': 'lets-request-steem-to-poloniex',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-21T12:42:15',
#    'trx_id': '5dbb8046452018c7b0f9d68346f7908beaa69b0a',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [72,
#   {'block': 788460,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 'prediction-voter-perceived-value',
#      'voter': 'anonymous',
#      'weight': 59}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-21T14:05:39',
#    'trx_id': '274887e5053fd35fdd13b093249ccfe845e3b9a1',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [73,
#   {'block': 798139,
#    'op': ['vote',
#     {'author': 'xeldal',
#      'permlink': 'how-to-liven-up-your-steem-posts-with-markdown',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-21T22:21:30',
#    'trx_id': '715f1f7345d71e9b0fb7c1df73f458c12a0a0f02',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [74,
#   {'block': 815200,
#    'op': ['comment',
#     {'author': 'ned',
#      'body': '\nned [4/20/16] [1:12 PM] \n\nVESTS WILL BE HEREBY REFERRED TO AS STEEM POWER (SMP) and moving from Steem to Steem Power will be referred to as “powering up”; moving from Steem Power to Steem referred to as “powering down.” For example, one can power down their Steem over a period of two years, yet one can power up their Steem instantly.  Powering up your Steem has several benefits, including automatic and recurring Steem rewards.  Additionally, Steem Power gives you voting power, which allows you to earn by casting votes on Steem, and because of this, Steem Power gives you the ability to earn more Steem Power and Steem Dollars. (edited)\n\n[1:13] \n\nSteemit.com and the Whitepaper will reflect these changes soon ..',
#      'json_metadata': '{}',
#      'parent_author': '',
#      'parent_permlink': 'steem',
#      'permlink': 'long-live-vests-',
#      'title': 'Long live Vests ... Vests are dead ...'}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T12:53:54',
#    'trx_id': '41c3053c44bd4affc7ea00130aa389c5ce0bb9ea',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [75,
#   {'block': 815210,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 'long-live-vests-',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T12:54:24',
#    'trx_id': '737f5a690c015b33cb736f2aa8275b05321ddd80',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [76,
#   {'block': 815766,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 'prediction-voter-perceived-value',
#      'voter': 'xeroc',
#      'weight': -100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T13:23:12',
#    'trx_id': '7a6679a9cad7a187d6ab87539f28927da59f035f',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [77,
#   {'block': 815780,
#    'op': ['comment',
#     {'author': 'xeroc',
#      'body': 'Is this what you "think" will happend or what you "whish" will happen?\t',
#      'json_metadata': '',
#      'parent_author': 'ned',
#      'parent_permlink': 'prediction-voter-perceived-value',
#      'permlink': 're-prediction-voter-perceived-value',
#      'title': 're: [PREDICTION] Voter Perceived Value'}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T13:23:54',
#    'trx_id': '9056b744580eed664106fee685bd5027333bc469',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [78,
#   {'block': 815995,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 'long-live-vests-',
#      'voter': 'xeldal',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T13:34:39',
#    'trx_id': '6eec4892cfde4439e9957477375437a65b8119aa',
#    'trx_in_block': 1,
#    'virtual_op': 0}],
#  [79,
#   {'block': 817026,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 'long-live-vests-',
#      'voter': 'jabbasteem',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T14:27:24',
#    'trx_id': 'a859fa058d7a722527eab20c8c73a8dc1ec7cab7',
#    'trx_in_block': 1,
#    'virtual_op': 0}],
#  [80,
#   {'block': 817522,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 'long-live-vests-',
#      'voter': 'xeroc',
#      'weight': -100}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T14:52:12',
#    'trx_id': '8d81875382f626321db2277bdd778afc0a669cfc',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [81,
#   {'block': 818645,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 'long-live-vests-',
#      'voter': 'enki',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T15:48:21',
#    'trx_id': '13f454e899dee9b7e9bd17ef618d2bafb460755e',
#    'trx_in_block': 1,
#    'virtual_op': 0}],
#  [82,
#   {'block': 819446,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 'long-live-vests-',
#      'voter': 'recursive',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T16:30:45',
#    'trx_id': '30f170a0fe19bed0ed36aea0ed539cb921552501',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [83,
#   {'block': 819519,
#    'op': ['comment',
#     {'author': 'recursive',
#      'body': 'Sounds good. Will you also change command names in the ... Steem Engine?',
#      'json_metadata': '{}',
#      'parent_author': 'ned',
#      'parent_permlink': 'long-live-vests-',
#      'permlink': 're-ned-long-live-vests--20160422t163416656z',
#      'title': ''}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T16:34:24',
#    'trx_id': '783056f7c27657b90989f9f94e717aebd927f35f',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [84,
#   {'block': 820978,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 'long-live-vests-',
#      'voter': 'clayop',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T17:48:18',
#    'trx_id': 'b36a48143ccaca9b8af7853e5c5f434ef08a7ea9',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [85,
#   {'block': 820985,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 'long-live-vests-',
#      'voter': 'riverhead',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T17:48:39',
#    'trx_id': 'b1813f93fda4cfae7a243737bdf566d6d6c8236f',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [86,
#   {'block': 821257,
#    'op': ['vote',
#     {'author': 'jabbasteem2',
#      'permlink': '4fu02f',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T18:02:27',
#    'trx_id': '26ae1ec841ecce572d3dd44feb9bf2059178dcd4',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [87,
#   {'block': 821329,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 'long-live-vests-',
#      'voter': 'nextgenwitness',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T18:06:03',
#    'trx_id': 'f61331cabd1a8313f068d58af737546542f3b9fd',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [88,
#   {'block': 821678,
#    'op': ['vote',
#     {'author': 'recursive',
#      'permlink': 're-ned-long-live-vests--20160422t163416656z',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T18:23:30',
#    'trx_id': '83230f379037636edda4a4451842df45e159ebca',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [89,
#   {'block': 821685,
#    'op': ['comment',
#     {'author': 'ned',
#      'body': 'Like this! may have to change the Twitter handle ;)',
#      'json_metadata': '{}',
#      'parent_author': 'recursive',
#      'parent_permlink': 're-ned-long-live-vests--20160422t163416656z',
#      'permlink': 're-recursive-re-ned-long-live-vests--20160422t163416656z-20160422t182350967z',
#      'title': ''}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T18:23:51',
#    'trx_id': 'c592553729ea6aa5f61394667fc94a5930e0ce88',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [90,
#   {'block': 821695,
#    'op': ['vote',
#     {'author': 'riverhead',
#      'permlink': 'witness-proposal-riverhead',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T18:24:21',
#    'trx_id': 'eb0bf19d7fb5a407212057301da51fae9ec3cbc7',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [91,
#   {'block': 822620,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 'long-live-vests-',
#      'voter': 'berniesanders',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T19:11:39',
#    'trx_id': '2189cd218992ccc7116a02370778113a95ea708e',
#    'trx_in_block': 1,
#    'virtual_op': 0}],
#  [92,
#   {'block': 822753,
#    'op': ['vote',
#     {'author': 'recursive',
#      'permlink': 'bertrand-russell-on-the-paradox-of-fools-and-wise-men',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T19:18:18',
#    'trx_id': '774897f09cdb86dc31d9efb33a677116397c5e9b',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [93,
#   {'block': 824196,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 're-recursive-re-ned-long-live-vests--20160422t163416656z-20160422t182350967z',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T20:33:21',
#    'trx_id': '976aef6cc9424303177a32e1dd524ede153888a6',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [94,
#   {'block': 824225,
#    'op': ['vote',
#     {'author': 'steempower',
#      'permlink': 're-ihashfury-re-justin-steem-is-now-listed-on-coinmarketcap-20160422t191759338z',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T20:34:51',
#    'trx_id': '55eba583997b4da068e50551715549224259ee74',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [95,
#   {'block': 824277,
#    'op': ['comment',
#     {'author': 'salus',
#      'body': 'A very welcomed change. Power Up! :mushroom:',
#      'json_metadata': '{}',
#      'parent_author': 'ned',
#      'parent_permlink': 'long-live-vests-',
#      'permlink': 're-ned-long-live-vests--20160422t203737579z',
#      'title': ''}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T20:37:36',
#    'trx_id': 'f926fe7c4fb1abbf4e9b00d0bdb3f7c91e3b3aa1',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [96,
#   {'block': 824994,
#    'op': ['vote',
#     {'author': 'salus',
#      'permlink': 're-ned-long-live-vests--20160422t203737579z',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T21:14:18',
#    'trx_id': '9f708b45655d9f2ca9417752ef565d2eb66d74b5',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [97,
#   {'block': 826650,
#    'op': ['vote',
#     {'author': 'donaldtrump',
#      'permlink': 'lets-talk-politics',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T22:42:54',
#    'trx_id': '08759166e3045ff630ab3074fc318d484ceb2761',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [98,
#   {'block': 826653,
#    'op': ['vote',
#     {'author': 'puppies',
#      'permlink': 'politics',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T22:43:03',
#    'trx_id': 'a0e0f58c003cdeb8d0ff6b360a4bc3427ec61947',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [99,
#   {'block': 826654,
#    'op': ['vote',
#     {'author': 'dan',
#      'permlink': 're-donaldtrump-lets-talk-politics-20160421t065424288z',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T22:43:06',
#    'trx_id': 'a982cd273a8ec6333065245cabdfb9389f187404',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [100,
#   {'block': 826656,
#    'op': ['vote',
#     {'author': 'kochindustries',
#      'permlink': 'your-votes-dont-matter-in-2016',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T22:43:12',
#    'trx_id': '1d5dbceb65411723ef7751d74daadc0787e187ca',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [101,
#   {'block': 826658,
#    'op': ['vote',
#     {'author': 'pharesim',
#      'permlink': 're-donaldtrump-lets-talk-politics-20160421t145915987z',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T22:43:18',
#    'trx_id': 'e28d3fd1c97934da894d0cbfdc8f132633da8edb',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [102,
#   {'block': 826660,
#    'op': ['vote',
#     {'author': 'puppies',
#      'permlink': 're-donaldtrump-lets-talk-politics-20160421t170756859z',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T22:43:24',
#    'trx_id': '2335c80302b7a25e08f79e8e5a5782e29980445d',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [103,
#   {'block': 826661,
#    'op': ['vote',
#     {'author': 'salus',
#      'permlink': 're-donaldtrump-lets-talk-politics-20160422t204800408z',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-22T22:43:27',
#    'trx_id': '6feccbef0c648edeeb09ad5d8de03e12dc4d1eba',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [104,
#   {'block': 835912,
#    'op': ['comment',
#     {'author': 'officialfuzzy',
#      'body': 'Just one question.  Could you change the title?  I have learned that some people may freak out without taking the time to look deeper :)\n\nHowever.  Back on point.  I will love to have steempower.  I will also be interested in figuring out "badges" and other interesting reputation increasing reward structures as steem evolves.  \nGamification is the future because the future is built by a generation of gamers.',
#      'json_metadata': '{}',
#      'parent_author': 'ned',
#      'parent_permlink': 're-recursive-re-ned-long-live-vests--20160422t163416656z-20160422t182350967z',
#      'permlink': 're-ned-re-recursive-re-ned-long-live-vests--20160422t163416656z-20160422t182350967z-20160423t063140042z',
#      'title': ''}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-23T06:31:39',
#    'trx_id': 'c337fe97c8906eaa6ce18c6811525a947c52c577',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [105,
#   {'block': 835917,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 'long-live-vests-',
#      'voter': 'officialfuzzy',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-23T06:31:54',
#    'trx_id': '0be5392e7c12601b4ab1c3d7a29ca08b41453bac',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [106,
#   {'block': 861120,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 'long-live-vests-',
#      'voter': 'justin',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-24T03:55:33',
#    'trx_id': '352cee6f6d3eb6f3cbe2662accf50344f46b99ac',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [107,
#   {'block': 861123,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 're-recursive-re-ned-long-live-vests--20160422t163416656z-20160422t182350967z',
#      'voter': 'justin',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-24T03:55:42',
#    'trx_id': '39b8dda7f3d02cb839ded8048bcd37d40cb41acd',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [108,
#   {'block': 863337,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 'long-live-vests-',
#      'voter': 'fminerten1',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-24T05:48:27',
#    'trx_id': '13e16ccbd48ff4dff5621ea8b6cef15a0c811ff7',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [109,
#   {'block': 864868,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 'long-live-vests-',
#      'voter': 'nextgencrypto',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-24T07:15:57',
#    'trx_id': '0f4f53bc3767ce80a8ab2b8af371eab74434e55f',
#    'trx_in_block': 1,
#    'virtual_op': 0}],
#  [110,
#   {'block': 872584,
#    'op': ['comment',
#     {'author': 'ihashfury',
#      'body': 'Vests are dead ...?\nI hope not!',
#      'json_metadata': '{}',
#      'parent_author': 'ned',
#      'parent_permlink': 'long-live-vests-',
#      'permlink': 're-ned-long-live-vests--20160424t134901100z',
#      'title': ''}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-24T13:49:00',
#    'trx_id': '462f5e0c821d385c3b6906139a9a8ca272dcf532',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [111,
#   {'block': 873184,
#    'op': ['comment',
#     {'author': 'ned',
#      'body': '@@ -711,8 +711,15 @@\n  soon ..\n+%0A%0Aedit*\n',
#      'json_metadata': '{}',
#      'parent_author': '',
#      'parent_permlink': 'steem',
#      'permlink': 'long-live-vests-',
#      'title': 'Long live Vests ... Vests are dead ...'}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-24T14:19:15',
#    'trx_id': '482ae8854f975fc1cebff53b838c01d46081b511',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [112,
#   {'block': 873314,
#    'op': ['comment',
#     {'author': 'ned',
#      'body': '@@ -70,17 +70,16 @@\n POWER (S\n-M\n P) and m\n',
#      'json_metadata': '{}',
#      'parent_author': '',
#      'parent_permlink': 'steem',
#      'permlink': 'long-live-vests-',
#      'title': 'Long live Vests ... Vests are dead ...'}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-24T14:25:48',
#    'trx_id': 'dfc8d253fe25d65c456d97d624361e73e33e8df2',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [113,
#   {'block': 873561,
#    'op': ['comment',
#     {'author': 'steempower',
#      'body': 'SteemPower is a much better name than vests imo +5%.\n\nwhile powering down does the automatic and recurring Steem reward still occur?',
#      'json_metadata': '{}',
#      'parent_author': 'ned',
#      'parent_permlink': 'long-live-vests-',
#      'permlink': 're-ned-long-live-vests--20160424t143818310z',
#      'title': ''}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-24T14:38:18',
#    'trx_id': '60b3791620be0a927d0dec67a85989fe18bbe39e',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [114,
#   {'block': 881108,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 'long-live-vests-',
#      'voter': 'joseph',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-24T20:57:15',
#    'trx_id': '28e21504a8024bb7a2dcd5bd8c0a7712d18f74bc',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [115,
#   {'block': 891113,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 'long-live-vests-',
#      'voter': 'pheonike',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-25T05:18:45',
#    'trx_id': '765da015a36e94976e243ac404019df7b0aa5ddd',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [116,
#   {'block': 892009,
#    'op': ['comment',
#     {'author': 'bitcube',
#      'body': 'If we can have a website showing the increasing power of STEEM POWER (ie conversion rate to SP), imagine the attention it would attract.',
#      'json_metadata': '{}',
#      'parent_author': 'ned',
#      'parent_permlink': 'long-live-vests-',
#      'permlink': 're-ned-long-live-vests--20160425t060339280z',
#      'title': ''}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-25T06:03:45',
#    'trx_id': '150edb441102b2d96c399866fc218956a9791241',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [117,
#   {'block': 892553,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 'long-live-vests-',
#      'voter': 'rainman',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-25T06:31:03',
#    'trx_id': '408274dab2045f262b2e2d1bd1a5d5eebdc08296',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [118,
#   {'block': 906226,
#    'op': ['account_witness_vote',
#     {'account': 'ned', 'approve': True, 'witness': 'kushed'}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-25T17:57:03',
#    'trx_id': 'c995db9b4dded2da50bb6b2eb399f5e6e4eb6d65',
#    'trx_in_block': 1,
#    'virtual_op': 0}],
#  [119,
#   {'block': 906239,
#    'op': ['account_witness_vote',
#     {'account': 'ned', 'approve': True, 'witness': 'au1nethyb1'}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-25T17:57:45',
#    'trx_id': '01fd82b946bc4d8b992627f41726602005db9143',
#    'trx_in_block': 2,
#    'virtual_op': 0}],
#  [120,
#   {'block': 906244,
#    'op': ['account_witness_vote',
#     {'account': 'ned', 'approve': True, 'witness': 'blocktrades'}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-25T17:58:03',
#    'trx_id': '30c23edc8829f512006a9ee315713868b05b9556',
#    'trx_in_block': 3,
#    'virtual_op': 0}],
#  [121,
#   {'block': 906250,
#    'op': ['account_witness_vote',
#     {'account': 'ned', 'approve': True, 'witness': 'steemychicken1'}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-25T17:58:27',
#    'trx_id': '157e9b3e53891d9e227534d6f3dd0e99d882ea4c',
#    'trx_in_block': 2,
#    'virtual_op': 0}],
#  [122,
#   {'block': 906254,
#    'op': ['account_witness_vote',
#     {'account': 'ned', 'approve': True, 'witness': 'smooth.witness'}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-25T17:58:42',
#    'trx_id': '46584404f12347b561b48f873d1963abbc9aa547',
#    'trx_in_block': 1,
#    'virtual_op': 0}],
#  [123,
#   {'block': 906257,
#    'op': ['account_witness_vote',
#     {'account': 'ned', 'approve': True, 'witness': 'datasecuritynode'}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-25T17:58:51',
#    'trx_id': '677e9b6d94732f0d7f98e54beaba8fc36b291769',
#    'trx_in_block': 1,
#    'virtual_op': 0}],
#  [124,
#   {'block': 906262,
#    'op': ['account_witness_vote',
#     {'account': 'ned', 'approve': True, 'witness': 'witness.svk'}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-25T17:59:06',
#    'trx_id': '7c35824d3f2abe18d0e06935488ffc2ca0b45025',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [125,
#   {'block': 906265,
#    'op': ['account_witness_vote',
#     {'account': 'ned', 'approve': True, 'witness': 'clayop'}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-25T17:59:15',
#    'trx_id': '7d1fdd4712a390090b708da605712d59f67a4ffd',
#    'trx_in_block': 2,
#    'virtual_op': 0}],
#  [126,
#   {'block': 906269,
#    'op': ['account_witness_vote',
#     {'account': 'ned', 'approve': True, 'witness': 'abit'}],
#    'op_in_trx': 0,
#    'timestamp': '2016-04-25T17:59:27',
# ...
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [963,
#   {'block': 2169017,
#    'op': ['vote',
#     {'author': 'm4ever',
#      'permlink': 'all-crypto-coin-traders--remember-the-fantasys-about-btc-priced-at-1-million-dollars',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-08T21:50:57',
#    'trx_id': 'b5b91b825e999be0c164d055752413aa612c53f6',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [964,
#   {'block': 2169035,
#    'op': ['vote',
#     {'author': 'nomoreheroes7',
#      'permlink': 'i-am-nomoreheroes7',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-08T21:51:51',
#    'trx_id': 'd558f2493569758d01cef0fb809b8ba5f839b875',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [965,
#   {'block': 2169573,
#    'op': ['vote',
#     {'author': 'stellabelle',
#      'permlink': 'hello-im-leah-and-im-an-information-addict',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-08T22:18:45',
#    'trx_id': 'c7d83794220e34e8093a0af50415c31cbad88522',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [966,
#   {'block': 2171507,
#    'op': ['vote',
#     {'author': 'wmougayar',
#      'permlink': 'hi-im-william-mougayar-from-toronto-canada',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-08T23:55:39',
#    'trx_id': 'bf81b843a9828002962367c918eec60820ebcac9',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [967,
#   {'block': 2171576,
#    'op': ['comment',
#     {'author': 'ned',
#      'body': 'Welcome, William!  How has the early internet era of startups been similar or different from the blockchain era?',
#      'json_metadata': '{"tags":["ama"]}',
#      'parent_author': 'wmougayar',
#      'parent_permlink': 'hi-im-william-mougayar-from-toronto-canada',
#      'permlink': 're-wmougayar-hi-im-william-mougayar-from-toronto-canada-20160608t235909205z',
#      'title': ''}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-08T23:59:09',
#    'trx_id': '1274abee085ebc0451c4277d408504bc3f949334',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [968,
#   {'block': 2171807,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 're-wmougayar-hi-im-william-mougayar-from-toronto-canada-20160608t235909205z',
#      'voter': 'cryptoctopus',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T00:10:45',
#    'trx_id': '89d6fbeae9102345bb9cf0ef4b961d17612f4af0',
#    'trx_in_block': 2,
#    'virtual_op': 0}],
#  [969,
#   {'block': 2171853,
#    'op': ['vote',
#     {'author': 'wmougayar',
#      'permlink': 're-cryptoctopus-re-wmougayar-hi-im-william-mougayar-from-toronto-canada-20160609t001157639z',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T00:13:03',
#    'trx_id': '3981597c763913616dd530f67e6102754ddb3770',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [970,
#   {'block': 2171874,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 're-wmougayar-hi-im-william-mougayar-from-toronto-canada-20160608t235909205z',
#      'voter': 'pfunk',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T00:14:06',
#    'trx_id': '9218d918985e50b167cc715e39d88b672e8c0917',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [971,
#   {'block': 2171896,
#    'op': ['comment',
#     {'author': 'wmougayar',
#      'body': "wow....in so many ways...many many ways, and I cover that a lot in my book where I refer to that analogy, because I was there from Day 1 with the Internet/Web and had a similar role, ie. to explain its evolution to businesses and the market. \nStartup-wise specifically, there is as much money and attention as there was in 2000 during the Internet days, BUT with an inventory of startups that look more like what we had in 1996-1997. \nI'd like to see more quality in blockchain related startups, and we are starting to see improvements across the board.",
#      'json_metadata': '{"tags":["ama"]}',
#      'parent_author': 'ned',
#      'parent_permlink': 're-wmougayar-hi-im-william-mougayar-from-toronto-canada-20160608t235909205z',
#      'permlink': 're-ned-re-wmougayar-hi-im-william-mougayar-from-toronto-canada-20160609t001557478z',
#      'title': ''}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T00:15:12',
#    'trx_id': '7b457129ceb7aff4deba2a0292788037ee4b2bac',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [972,
#   {'block': 2171953,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 're-wmougayar-hi-im-william-mougayar-from-toronto-canada-20160608t235909205z',
#      'voter': 'nextgencrypto',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T00:18:06',
#    'trx_id': 'e745df9c3b59edd9af0ebe16858a44726e02aeb5',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [973,
#   {'block': 2172036,
#    'op': ['vote',
#     {'author': 'wmougayar',
#      'permlink': 're-ned-re-wmougayar-hi-im-william-mougayar-from-toronto-canada-20160609t001557478z',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T00:22:15',
#    'trx_id': 'ea0ac1b2db4d5bc9663dd62d611ff2dd8f39e49f',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [974,
#   {'block': 2172648,
#    'op': ['comment',
#     {'author': 'ned',
#      'body': 'William, thank you for joining us tonight, you had great responses! Thank you everyone who asked questions.  This was a very successful, first ever, Steem AMA',
#      'json_metadata': '{"tags":["ama"]}',
#      'parent_author': 'wmougayar',
#      'parent_permlink': 'hi-im-william-mougayar-from-toronto-canada',
#      'permlink': 're-wmougayar-hi-im-william-mougayar-from-toronto-canada-20160609t005250972z',
#      'title': ''}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T00:52:51',
#    'trx_id': 'ddb8f313e71f4b1a9abe25b49c7b141e36a19acc',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [975,
#   {'block': 2172660,
#    'op': ['comment',
#     {'author': 'ned',
#      'body': '@@ -151,8 +151,57 @@\n teem\n+it\n  AMA\n+, and *it will forever live on the blockchain!*\n',
#      'json_metadata': '{"tags":["ama"]}',
#      'parent_author': 'wmougayar',
#      'parent_permlink': 'hi-im-william-mougayar-from-toronto-canada',
#      'permlink': 're-wmougayar-hi-im-william-mougayar-from-toronto-canada-20160609t005250972z',
#      'title': ''}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T00:53:27',
#    'trx_id': 'b7d9ca6811519539f2f66c2132142a2fa47ac0e1',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [976,
#   {'block': 2172784,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 're-wmougayar-hi-im-william-mougayar-from-toronto-canada-20160608t235909205z',
#      'voter': 'boatymcboatface',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T00:59:39',
#    'trx_id': 'c2d4b8397dba8b0c47e0bd31ad4030702a05c887',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [977,
#   {'block': 2172794,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 're-wmougayar-hi-im-william-mougayar-from-toronto-canada-20160608t235909205z',
#      'voter': 'rossco99',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T01:00:09',
#    'trx_id': '94cec0d5ea93ed7dcfcb27b3b4d7df6de7c49f07',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [978,
#   {'block': 2172957,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 're-wmougayar-hi-im-william-mougayar-from-toronto-canada-20160609t005250972z',
#      'voter': 'chitty',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T01:08:18',
#    'trx_id': '7c4538208a3530670f5653c8a2768c9bfa70cdfc',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [979,
#   {'block': 2173002,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 're-wmougayar-hi-im-william-mougayar-from-toronto-canada-20160608t235909205z',
#      'voter': 'konelectric',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T01:10:33',
#    'trx_id': '06a6d38986475b4dbe86376b4a730b8e7023f507',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [980,
#   {'block': 2173023,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 're-wmougayar-hi-im-william-mougayar-from-toronto-canada-20160609t005250972z',
#      'voter': 'cryptoctopus',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T01:11:36',
#    'trx_id': '93e1c0627109327321bf540d5d92d86f249419e3',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [981,
#   {'block': 2173056,
#    'op': ['comment',
#     {'author': 'cryptoctopus',
#      'body': 'https://media.giphy.com/media/lXiRy0RCPLMQSVqx2/giphy.gif',
#      'json_metadata': '{"tags":["ama"]}',
#      'parent_author': 'ned',
#      'parent_permlink': 're-wmougayar-hi-im-william-mougayar-from-toronto-canada-20160609t005250972z',
#      'permlink': 're-ned-re-wmougayar-hi-im-william-mougayar-from-toronto-canada-20160609t011319120z',
#      'title': ''}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T01:13:15',
#    'trx_id': '33e70ce34c45f0e14a34d49a116f3d858dca28de',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [982,
#   {'block': 2173069,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 're-theshell-my-life-as-the-wife-of-rossco99-20160603t123316029z',
#      'voter': 'boatymcboatface',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T01:13:54',
#    'trx_id': '638d66096f17df3fc7693dd9c2274c16e0e602f5',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [983,
#   {'block': 2173288,
#    'op': ['comment',
#     {'author': 'wmougayar',
#      'body': "Thank you Ned and everybody. Great questions overall. Thank you, Steemit. \nFeel free to email me, anyone. You can AMA on email too wmougayar@gmail.com \nAnd don't hesitate to get The Business Blockchain book on Amazon and write a review if you like it.",
#      'json_metadata': '{"tags":["ama"]}',
#      'parent_author': 'ned',
#      'parent_permlink': 're-wmougayar-hi-im-william-mougayar-from-toronto-canada-20160609t005250972z',
#      'permlink': 're-ned-re-wmougayar-hi-im-william-mougayar-from-toronto-canada-20160609t012536587z',
#      'title': ''}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T01:24:51',
#    'trx_id': 'da377692e49f3f7d68979a54f04aa0bf1e941cd5',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [984,
#   {'block': 2173330,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 're-wmougayar-hi-im-william-mougayar-from-toronto-canada-20160608t235909205z',
#      'voter': 'anon',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T01:26:57',
#    'trx_id': 'd0f9890cb87dd108c58dfb92567fa8580a60e275',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [985,
#   {'block': 2173361,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 're-wmougayar-hi-im-william-mougayar-from-toronto-canada-20160609t005250972z',
#      'voter': 'anon',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T01:28:30',
#    'trx_id': 'decd5d212ab44cea6429cda1abbedf1d793898e2',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [986,
#   {'block': 2173395,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 're-wmougayar-hi-im-william-mougayar-from-toronto-canada-20160609t005250972z',
#      'voter': 'code',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T01:30:12',
#    'trx_id': '12f9640d71310eab96b0ae0b904eeb4f4f748e64',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [987,
#   {'block': 2173407,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 're-wmougayar-hi-im-william-mougayar-from-toronto-canada-20160609t005250972z',
#      'voter': 'pfunk',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T01:30:48',
#    'trx_id': '0ef824489fdd3a3eefdec9efab21598633f2419f',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [988,
#   {'block': 2173531,
#    'op': ['vote',
#     {'author': 'val',
#      'permlink': 'my-worst-flight-experience--american-airlines-assigned-much-smaller-planet-for-the-flight-from',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T01:37:00',
#    'trx_id': '5630eb0431d66bb010693ea31eef148ef50fbec1',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [989,
#   {'block': 2173580,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 're-wmougayar-hi-im-william-mougayar-from-toronto-canada-20160609t005250972z',
#      'voter': 'jsc',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T01:39:27',
#    'trx_id': 'e5cd37c223a7948000baaccf6dc91fdd20ef022e',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [990,
#   {'block': 2173846,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 're-wmougayar-hi-im-william-mougayar-from-toronto-canada-20160608t235909205z',
#      'voter': 'steempowered',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T01:52:45',
#    'trx_id': '75ea6f534f0dce20b91c707eda03a48144b286d0',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [991,
#   {'block': 2173993,
#    'op': ['vote',
#     {'author': 'stellabelle',
#      'permlink': 'i-used-to-be-hot',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T02:00:06',
#    'trx_id': 'ed0fb8b73f83a6f33fc0fdd30e9415a4919a8107',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [992,
#   {'block': 2174493,
#    'op': ['vote',
#     {'author': 'daenerys',
#      'permlink': 'spoiler-alert',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T02:25:15',
#    'trx_id': '22f52778cb5cb31e6e1d7a7ca9eafd63bccb8d1d',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [993,
#   {'block': 2175311,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 're-wmougayar-hi-im-william-mougayar-from-toronto-canada-20160608t235909205z',
#      'voter': 'judyhopps',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T03:06:09',
#    'trx_id': '9896bdf95c0c78afeb6dcde93a8afed2a67f6764',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [994,
#   {'block': 2176424,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 're-bee-tollworthy-how-to-steemit-20160608t151721304z',
#      'voter': 'beerbloke',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T04:01:57',
#    'trx_id': '00892254db9024d3d0c283b622b46aabb2f674c8',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [995,
#   {'block': 2176906,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 'community-manager-job-posting',
#      'voter': 'stellabelle',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T04:26:03',
#    'trx_id': 'b285be5c842e080872a4036c0dd1e0cf37d3d84a',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [996,
#   {'block': 2176952,
#    'op': ['comment',
#     {'author': 'stellabelle',
#      'body': "I'm definitely interested in learning more about this position. Have you completed the job description yet and if so, what's the link?",
#      'json_metadata': '{"tags":["opportunities"]}',
#      'parent_author': 'ned',
#      'parent_permlink': 'community-manager-job-posting',
#      'permlink': 're-ned-community-manager-job-posting-20160609t042824444z',
#      'title': ''}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T04:28:24',
#    'trx_id': '5a021ca6aec2a7b31c4344a069bddeede1485d08',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [997,
#   {'block': 2180507,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 're-wmougayar-hi-im-william-mougayar-from-toronto-canada-20160609t005250972z',
#      'voter': 'liondani',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T07:27:03',
#    'trx_id': '336abe7d44dd4ae4416d62f34d7367392afdd50c',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [998,
#   {'block': 2183626,
#    'op': ['vote',
#     {'author': 'ned',
#      'permlink': 're-wmougayar-hi-im-william-mougayar-from-toronto-canada-20160609t005250972z',
#      'voter': 'ihashfury',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T10:03:12',
#    'trx_id': 'a54e4a5d762d76da7ebf9571c769786002640e75',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [999,
#   {'block': 2188942,
#    'op': ['vote',
#     {'author': 'benjojo',
#      'permlink': 'steme-crazy-2',
#      'voter': 'ned',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2016-06-09T14:29:33',
#    'trx_id': 'd8e25f889a4790fb9597e5b40280d276bd9cfca8',
#    'trx_in_block': 0,
#    'virtual_op': 0}]]

# %%
tr = list(filter(lambda x: x[1]['op'][0]=='transfer', osszes))

# %%
tr[2][1]['op'][1]['amount'].split(' ')[1]
# Out:
# 'STEEM'

# %%
def get_tr_pd(all_tr):
    #filter
    transactions = list(filter(lambda x: x[1]['op'][0]=='transfer', all_tr))
    
    just_tr = list(map(lambda x: {'amount': x[1]['op'][1]['amount'],
                                 'from': x[1]['op'][1]['from'],
                                 'memo': x[1]['op'][1]['memo'],
                                 'to': x[1]['op'][1]['to'],
                                 'currency': x[1]['op'][1]['amount'].split(' ')[1],
                                 'currency_amount': float(x[1]['op'][1]['amount'].split(' ')[0]),
                                 'timestamp': x[1]['timestamp']},transactions))
    
    return(pd.DataFrame(just_tr))

# %%
df = get_tr_pd(osszes)
df.sort_values(by='currency_amount', ascending=False)

# %%
df.sort_values(by='currency_amount', ascending=False)
# Out:
#                 amount currency  currency_amount              from  \
# 667  1600662.980 STEEM    STEEM      1600662.980               ned
# 223   794260.000 STEEM    STEEM       794260.000               ned
# 188   693201.000 STEEM    STEEM       693201.000               ned
# 238   440083.000 STEEM    STEEM       440083.000               ned
# 609   200000.000 STEEM    STEEM       200000.000               ned
# 187   200000.000 STEEM    STEEM       200000.000               ned
# 597   110872.084 STEEM    STEEM       110872.084               ned
# 118   106447.897 STEEM    STEEM       106447.897               ned
# 107    55000.000 STEEM    STEEM        55000.000               ned
# 108    55000.000 STEEM    STEEM        55000.000               ned
# 82     30844.097 STEEM    STEEM        30844.097               ned
# 417    30000.000 STEEM    STEEM        30000.000               ned
# 105    21900.949 STEEM    STEEM        21900.949               ned
# 70     21000.000 STEEM    STEEM        21000.000               ned
# 71     12010.102 STEEM    STEEM        12010.102               ned
# 97     10000.000 STEEM    STEEM        10000.000               ned
# 103    10000.000 STEEM    STEEM        10000.000               ned
# 100    10000.000 STEEM    STEEM        10000.000               ned
# 131     7414.742 STEEM    STEEM         7414.742       steemsports
# 130     4000.000 STEEM    STEEM         4000.000               ned
# 112       3835.676 SBD      SBD         3835.676               ned
# 94      3000.000 STEEM    STEEM         3000.000               ned
# 93      3000.000 STEEM    STEEM         3000.000               ned
# 659     1000.000 STEEM    STEEM         1000.000               ned
# 594     1000.000 STEEM    STEEM         1000.000               ned
# 147     1000.000 STEEM    STEEM         1000.000               ned
# 656     1000.000 STEEM    STEEM         1000.000               ned
# 657     1000.000 STEEM    STEEM         1000.000               ned
# 658     1000.000 STEEM    STEEM         1000.000               ned
# 128        975.000 SBD      SBD          975.000               ned
# ..                 ...      ...              ...               ...
# 297          0.001 SBD      SBD            0.001             yehey
# 340          0.001 SBD      SBD            0.001       audreylogan
# 342          0.001 SBD      SBD            0.001        ajaytiwari
# 374        0.001 STEEM    STEEM            0.001         mkdouglas
# 361          0.001 SBD      SBD            0.001       trickstar95
# 373          0.001 SBD      SBD            0.001             mars9
# 372        0.001 STEEM    STEEM            0.001         wandimaru
# 371          0.001 SBD      SBD            0.001        ajaytiwari
# 370        0.001 STEEM    STEEM            0.001          aaqib11b
# 369        0.001 STEEM    STEEM            0.001          starlost
# 368        0.001 STEEM    STEEM            0.001  stefan.steynberg
# 367        0.001 STEEM    STEEM            0.001         katiesato
# 366          0.001 SBD      SBD            0.001           dianna1
# 365        0.001 STEEM    STEEM            0.001       wattoowhale
# 364        0.001 STEEM    STEEM            0.001               jga
# 363        0.001 STEEM    STEEM            0.001           the-ord
# 360        0.001 STEEM    STEEM            0.001        steemretro
# 343          0.001 SBD      SBD            0.001               a-7
# 357          0.001 SBD      SBD            0.001       trickstar95
# 356          0.001 SBD      SBD            0.001      gordonramsay
# 354          0.001 SBD      SBD            0.001             jinzo
# 353        0.001 STEEM    STEEM            0.001            gex231
# 352          0.001 SBD      SBD            0.001            bulsik
# 351          0.001 SBD      SBD            0.001  donateforcharity
# 350        0.001 STEEM    STEEM            0.001      taimoorahmad
# 348          0.001 SBD      SBD            0.001      hakeemshah96
# 347          0.001 SBD      SBD            0.001              snug
# 346        0.001 STEEM    STEEM            0.001      taimoorahmad
# 344        0.001 STEEM    STEEM            0.001               a-5
# 677        0.001 STEEM    STEEM            0.001        disenchant
#
#                                                   memo            timestamp  \
# 667                                0b422698a383407a88b  2018-10-20T21:13:12
# 223                                                     2017-08-11T13:52:15
# 188                                                     2017-06-28T21:39:51
# 238                                                     2017-08-23T21:55:27
# 609                                                     2018-07-06T19:25:12
# 187                                                     2017-06-28T21:24:39
# 597                                                     2018-06-22T19:55:39
# 118                                   bdc163cd42c4ff45  2016-11-04T20:42:33
# 107                                   bdc163cd42c4ff45  2016-10-09T21:23:00
# 108                                be4cb840d47246eb80b  2016-10-09T21:23:51
# 82                                    bdc163cd42c4ff45  2016-09-07T23:48:48
# 417                                                     2018-01-29T03:31:21
# 105                                   bdc163cd42c4ff45  2016-10-05T03:30:03
# 70                                    bdc163cd42c4ff45  2016-09-01T16:00:42
# 71                                    bdc163cd42c4ff45  2016-09-01T21:09:45
# 97                                    bdc163cd42c4ff45  2016-09-24T16:34:51
# 103                                   bdc163cd42c4ff45  2016-09-30T02:09:09
# 100                                be4cb840d47246eb80b  2016-09-26T02:06:15
# 131  Winner - trx_id: 15dcf9f47b7666244c9d3b370adaf...  2017-02-06T17:06:12
# 130                   f731cb8739924653a5b294a6bf5c788c  2017-02-05T18:37:21
# 112                                                     2016-10-17T06:51:30
# 94                                    bdc163cd42c4ff45  2016-09-22T13:06:48
# 93                                    bdc163cd42c4ff45  2016-09-19T18:59:06
# 659                                                     2018-10-18T23:12:57
# 594                                                     2018-06-21T21:18:45
# 147                                for memechallengers  2017-03-20T01:45:21
# 656                                                     2018-10-18T23:11:24
# 657                                                     2018-10-18T23:11:54
# 658                                                     2018-10-18T23:12:30
# 128  I watched your video and know you can reach yo...  2017-01-01T19:15:33
# ..                                                 ...                  ...
# 297  Hi Ned good afternoon. It's a long shot but wo...  2017-10-24T21:54:15
# 340  Sir, I want 1000k sp delegation. I will pay $5...  2017-11-23T08:27:51
# 342  Dear sir, please delegate me 100k steem power ...  2017-11-24T02:14:24
# 374  Steem transaction memos and how the Steem bloc...  2017-12-23T22:02:27
# 361   I need 100K SP and I will send you 65 SBD daily.  2017-12-10T21:44:18
# 373   One society All of us have a new year to real...  2017-12-23T12:51:24
# 372                                          sincerely  2017-12-23T04:21:15
# 371     sir, delegate me100 k for 60 sbd daily. please  2017-12-21T17:03:15
# 370  mam.....christmas is coming so i along with so...  2017-12-21T08:50:00
# 369  hi i am new in steemit please help, this is my...  2017-12-19T11:49:33
# 368  Hey there Ned , if you have some time , would ...  2017-12-15T22:42:51
# 367  Big offer!!! Just send $0.2 SBD to @katiesato ...  2017-12-15T18:33:15
# 366  Hello ❤https://steemit.com/tr/@dianna1/dogecoi...  2017-12-13T14:30:51
# 365  Hi Sir  I Need 100k Steem Power I will Pay You...  2017-12-13T05:37:45
# 364  Infographic about the Author and Curator rewar...  2017-12-12T20:43:45
# 363  I notice that a lot of the steemit members ,us...  2017-12-12T16:00:30
# 360  Congratulations on achieving a highscore of 14...  2017-12-10T05:40:36
# 343  Dear sir, i want 200k steem power. I will pay ...  2017-11-24T05:43:21
# 357  Hello Sir Please delegate 100k Steem Power to ...  2017-12-08T18:17:36
# 356  Get your post resteemed over 50000+ followers ...  2017-12-08T17:44:36
# 354  here is the top 5 crypto wallets. https://stee...  2017-12-05T16:40:15
# 353  Hello Ned, I'd like to rent 100k SP from you, ...  2017-12-05T09:18:42
# 352  Dear @ned. Below guys, @ngc @newsflash @nextge...  2017-12-03T17:05:33
# 351  #tcNbMs5KxPypKwSMTeU8Wg4HxXvkdYG424XPdDorRshRe...  2017-12-03T06:44:06
# 350  With due respect. Would you please delegate me...  2017-12-01T06:52:15
# 348  Dear Sir I Heard You Help Steem Users But Sir ...  2017-11-29T20:04:00
# 347                                                  🍕  2017-11-29T16:37:15
# 346  Sir I paid 5.095sbd for steem but didn't get i...  2017-11-28T18:26:51
# 344  Just send $1 SBD to @a-5 with your post url on...  2017-11-27T14:45:39
# 677                                                 HI  2018-10-29T14:44:51
#
#                 to
# 667        bittrex
# 223          alpha
# 188       firefire
# 238          alpha
# 609      brixtongg
# 187       firefire
# 597      brixtongg
# 118       poloniex
# 107       poloniex
# 108        bittrex
# 82        poloniex
# 417    southorange
# 105       poloniex
# 70        poloniex
# 71        poloniex
# 97        poloniex
# 103       poloniex
# 100        bittrex
# 131            ned
# 130    steemsports
# 112            ned
# 94        poloniex
# 93        poloniex
# 659    test-safari
# 594      brixtongg
# 147        fibra59
# 656      oscarfate
# 657    test-safari
# 658      oscarfate
# 128  aidancloquell
# ..             ...
# 297            ned
# 340            ned
# 342            ned
# 374            ned
# 361            ned
# 373            ned
# 372            ned
# 371            ned
# 370            ned
# 369            ned
# 368            ned
# 367            ned
# 366            ned
# 365            ned
# 364            ned
# 363            ned
# 360            ned
# 343            ned
# 357            ned
# 356            ned
# 354            ned
# 353            ned
# 352            ned
# 351            ned
# 350            ned
# 348            ned
# 347            ned
# 346            ned
# 344            ned
# 677            ned
#
# [678 rows x 7 columns]

# %%
misrori = get_all_tr('misrori')
# Out:
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000

# %%
df = get_tr_pd(misrori)
df.sort_values(by='currency_amount', ascending=False)
# Out:
#               amount currency  currency_amount         from  \
# 1      371.990 STEEM    STEEM          371.990      bittrex
# 272    199.624 STEEM    STEEM          199.624  blocktrades
# 273    199.624 STEEM    STEEM          199.624      misrori
# 4613   135.918 STEEM    STEEM          135.918      misrori
# 5331    80.209 STEEM    STEEM           80.209      misrori
# 160     51.182 STEEM    STEEM           51.182   postdoctor
# 10201   50.000 STEEM    STEEM           50.000   postdoctor
# 11485   50.000 STEEM    STEEM           50.000   postdoctor
# 8504      50.000 SBD      SBD           50.000   postdoctor
# 271     47.290 STEEM    STEEM           47.290      misrori
# 8821      40.000 SBD      SBD           40.000   postdoctor
# 226     33.100 STEEM    STEEM           33.100   postdoctor
# 10706   30.000 STEEM    STEEM           30.000   postdoctor
# 8125      30.000 SBD      SBD           30.000   postdoctor
# 159       28.362 SBD      SBD           28.362      misrori
# 10922   23.000 STEEM    STEEM           23.000   postdoctor
# 150       20.000 SBD      SBD           20.000      misrori
# 5680      20.000 SBD      SBD           20.000      misrori
# 7795      20.000 SBD      SBD           20.000   postdoctor
# 5746      18.990 SBD      SBD           18.990      bittrex
# 7516      12.437 SBD      SBD           12.437   postdoctor
# 8184    12.000 STEEM    STEEM           12.000      misrori
# 6878      12.000 SBD      SBD           12.000   postdoctor
# 8183    11.000 STEEM    STEEM           11.000      misrori
# 3824    10.100 STEEM    STEEM           10.100      misrori
# 106       10.000 SBD      SBD           10.000      misrori
# 136       10.000 SBD      SBD           10.000      misrori
# 110       10.000 SBD      SBD           10.000      misrori
# 4058      10.000 SBD      SBD           10.000     surfyogi
# 6615      10.000 SBD      SBD           10.000   postdoctor
# ...              ...      ...              ...          ...
# 7805       0.001 SBD      SBD            0.001         haji
# 7803       0.001 SBD      SBD            0.001         haji
# 7800       0.001 SBD      SBD            0.001         haji
# 7923       0.001 SBD      SBD            0.001   resteembot
# 7966       0.001 SBD      SBD            0.001         haji
# 8119       0.001 SBD      SBD            0.001         haji
# 8065       0.001 SBD      SBD            0.001         haji
# 8115       0.001 SBD      SBD            0.001         haji
# 8110       0.001 SBD      SBD            0.001         haji
# 8106       0.001 SBD      SBD            0.001         haji
# 8102       0.001 SBD      SBD            0.001         haji
# 8099       0.001 SBD      SBD            0.001         haji
# 8097       0.001 SBD      SBD            0.001         haji
# 8093       0.001 SBD      SBD            0.001         haji
# 8089       0.001 SBD      SBD            0.001         haji
# 8086       0.001 SBD      SBD            0.001         haji
# 8070       0.001 SBD      SBD            0.001         haji
# 8061       0.001 SBD      SBD            0.001         haji
# 7970       0.001 SBD      SBD            0.001         haji
# 8057       0.001 SBD      SBD            0.001         haji
# 8055       0.001 SBD      SBD            0.001         haji
# 8051       0.001 SBD      SBD            0.001         haji
# 8041       0.001 SBD      SBD            0.001         haji
# 8039       0.001 SBD      SBD            0.001         haji
# 8015       0.001 SBD      SBD            0.001         haji
# 8013       0.001 SBD      SBD            0.001         haji
# 8009       0.001 SBD      SBD            0.001         haji
# 7994       0.001 SBD      SBD            0.001         haji
# 7972       0.001 SBD      SBD            0.001         haji
# 5898       0.001 SBD      SBD            0.001         haji
#
#                                                     memo            timestamp  \
# 1      STM6o5S1qaNxjabygKvbLsNGt9HRY7rtmbZRE9bkenLS9V...  2017-07-19T06:47:48
# 272                                                       2018-02-06T05:30:36
# 273                                                       2018-02-06T06:33:24
# 4613                                           105070816  2018-05-01T10:21:21
# 5331                                           105070816  2018-05-23T06:30:42
# 160                                                       2018-02-01T13:53:51
# 10201                                             refund  2018-09-14T05:49:39
# 11485  Hy, Sorry for missing your post! I have refoun...  2018-10-23T11:11:00
# 8504   Hy, Sorry for missing your post! I have refoun...  2018-08-06T16:37:39
# 271                                                       2018-02-05T19:28:48
# 8821                               sorry, i refund you!   2018-08-13T10:47:18
# 226                                                       2018-02-04T14:34:18
# 10706                              sorry, i refund you!   2018-10-03T08:04:24
# 8125   Hy, Sorry for missing your post! I have refoun...  2018-07-30T04:40:21
# 159                                                       2018-02-01T13:41:03
# 10922                              sorry, i refund you!   2018-10-08T07:34:30
# 150                                                       2018-01-29T09:42:57
# 5680                                 3722c7e95434406fab1  2018-06-02T15:11:12
# 7795                                Sorry, i refund you!  2018-07-23T13:47:24
# 5746                                              vissza  2018-06-04T08:11:42
# 7516                                 sorry, i refund you  2018-07-18T05:11:51
# 8184                                           101944583  2018-07-31T08:02:30
# 6878                                 sorry, i refund you  2018-07-02T05:05:15
# 8183                                           101985887  2018-07-31T08:01:54
# 3824                                           105070816  2018-04-10T16:14:39
# 106    https://steemit.com/steem/@misrori/uppcomming-...  2018-01-10T15:25:21
# 136    https://steemit.com/steem/@misrori/uppcomming-...  2018-01-22T04:49:57
# 110    https://steemit.com/steem/@misrori/uppcomming-...  2018-01-14T12:24:30
# 4058   #6DnKiQNu1PgUxQBSMhVjdworNmiQAVMxTdCyVGgYrxHeA...  2018-04-16T17:51:06
# 6615   Hy, Sorry for missing your post! I have refoun...  2018-06-25T17:51:54
# ...                                                  ...                  ...
# 7805   🌹Hello my dear friend 🌐 Resteem your post ✅9,0...  2018-07-23T18:21:36
# 7803   🌹Hello my dear friend 🌐 Resteem your post ✅9,0...  2018-07-23T16:15:36
# 7800   🌹Hello my dear friend 🌐 Resteem your post ✅9,0...  2018-07-23T15:15:39
# 7923                                              A gift  2018-07-26T00:17:12
# 7966   🌹Hello my dear friend 🌐 Resteem your post ✅9,0...  2018-07-26T22:16:30
# 8119   🌹Hello my dear friend 🌐 Resteem your post ✅9,0...  2018-07-29T23:19:03
# 8065   🌹Hello my dear friend 🌐 Resteem your post ✅9,0...  2018-07-28T22:17:42
# 8115   🌹Hello my dear friend 🌐 Resteem your post ✅9,0...  2018-07-29T20:55:03
# 8110   🌹Hello my dear friend 🌐 Resteem your post ✅9,0...  2018-07-29T18:24:27
# 8106   🌹Hello my dear friend 🌐 Resteem your post ✅9,0...  2018-07-29T17:25:06
# 8102   🌹Hello my dear friend 🌐 Resteem your post ✅9,0...  2018-07-29T15:15:36
# 8099   🌹Hello my dear friend 🌐 Resteem your post ✅9,0...  2018-07-29T14:17:48
# 8097   🌹Hello my dear friend 🌐 Resteem your post ✅9,0...  2018-07-29T13:16:39
# 8093   🌹Hello my dear friend 🌐 Resteem your post ✅9,0...  2018-07-29T12:17:45
# 8089   🌹Hello my dear friend 🌐 Resteem your post ✅9,0...  2018-07-29T11:16:45
# 8086   🌹Hello my dear friend 🌐 Resteem your post ✅9,0...  2018-07-29T10:16:42
# 8070   🌹Hello my dear friend 🌐 Resteem your post ✅9,0...  2018-07-29T00:16:39
# 8061   🌹Hello my dear friend 🌐 Resteem your post ✅9,0...  2018-07-28T21:21:36
# 7970   🌹Hello my dear friend 🌐 Resteem your post ✅9,0...  2018-07-26T23:17:33
# 8057   🌹Hello my dear friend 🌐 Resteem your post ✅9,0...  2018-07-28T19:21:27
# 8055   🌹Hello my dear friend 🌐 Resteem your post ✅9,0...  2018-07-28T18:22:48
# 8051   🌹Hello my dear friend 🌐 Resteem your post ✅9,0...  2018-07-28T17:19:03
# 8041   🌹Hello my dear friend 🌐 Resteem your post ✅9,0...  2018-07-28T12:17:48
# 8039   🌹Hello my dear friend 🌐 Resteem your post ✅9,0...  2018-07-28T11:18:12
# 8015   🌹Hello my dear friend 🌐 Resteem your post ✅9,0...  2018-07-27T23:17:39
# 8013   🌹Hello my dear friend 🌐 Resteem your post ✅9,0...  2018-07-27T22:16:45
# 8009   🌹Hello my dear friend 🌐 Resteem your post ✅9,0...  2018-07-27T21:18:54
# 7994   🌹Hello my dear friend 🌐 Resteem your post ✅9,0...  2018-07-27T12:17:03
# 7972   🌹Hello my dear friend 🌐 Resteem your post ✅9,0...  2018-07-27T00:16:36
# 5898   🌹Hello my dear friend 🌐 Resteem your post; ✅8,...  2018-06-08T23:15:30
#
#                 to
# 1          misrori
# 272        misrori
# 273     postdoctor
# 4613   deepcrypto8
# 5331   deepcrypto8
# 160        misrori
# 10201      misrori
# 11485      misrori
# 8504       misrori
# 271     postdoctor
# 8821       misrori
# 226        misrori
# 10706      misrori
# 8125       misrori
# 159     postdoctor
# 10922      misrori
# 150     postdoctor
# 5680       bittrex
# 7795       misrori
# 5746       misrori
# 7516       misrori
# 8184   deepcrypto8
# 6878       misrori
# 8183   deepcrypto8
# 3824   deepcrypto8
# 106         rocky1
# 136    appreciator
# 110         rocky1
# 4058       misrori
# 6615       misrori
# ...            ...
# 7805       misrori
# 7803       misrori
# 7800       misrori
# 7923       misrori
# 7966       misrori
# 8119       misrori
# 8065       misrori
# 8115       misrori
# 8110       misrori
# 8106       misrori
# 8102       misrori
# 8099       misrori
# 8097       misrori
# 8093       misrori
# 8089       misrori
# 8086       misrori
# 8070       misrori
# 8061       misrori
# 7970       misrori
# 8057       misrori
# 8055       misrori
# 8051       misrori
# 8041       misrori
# 8039       misrori
# 8015       misrori
# 8013       misrori
# 8009       misrori
# 7994       misrori
# 7972       misrori
# 5898       misrori
#
# [11796 rows x 7 columns]

# %%
misrori[-500:]
# Out:
# [[62871,
#   {'block': 27218989,
#    'op': ['transfer',
#     {'amount': '0.059 STEEM',
#      'from': 'edensgarden',
#      'memo': 'Round Earnings - 0.059 STEEM | Thank you!',
#      'to': 'misrori'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T01:34:57',
#    'trx_id': '2159ce48948c80d5fa34225c9a73a4fd46b531b0',
#    'trx_in_block': 8,
#    'virtual_op': 0}],
#  [62872,
#   {'block': 27219794,
#    'op': ['author_reward',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-golem-22-october-2018',
#      'sbd_payout': '0.033 SBD',
#      'steem_payout': '0.000 STEEM',
#      'vesting_payout': '88.754125 VESTS'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T02:15:15',
#    'trx_id': '0000000000000000000000000000000000000000',
#    'trx_in_block': 4294967295,
#    'virtual_op': 6}],
#  [62873,
#   {'block': 27219795,
#    'op': ['comment',
#     {'author': 'misrori',
#      'body': '<center><h1> Here you can see the latest 10 twitts about GXChain</h1></center>\n\n\n\n\n<center><h1> [Andrew_Marshall](https://twitter.com/Andrew_Marshall)</h1></center>\n<center><h3>2018-10-27 19:16:25</h3></center>\n\n\nRT @p2pmoneyshop: Tuple and GXChain bid to build P2P data exchange marketplace https://t.co/ukMkj19XtI via @Finextra\n\n\n<hr>\n\n\n<center><h1> [_NXTalpha](https://twitter.com/_NXTalpha)</h1></center>\n<center><h3>2018-10-26 16:36:03</h3></center>\n\n\n“The idea of a #decentralized #data #marketplace has been gaining broader traction of late, as individuals and comp… https://t.co/ty9FdVWt9C\n\n\n<hr>\n\n\n<center><h1> [Andrew_Marshall](https://twitter.com/Andrew_Marshall)</h1></center>\n<center><h3>2018-10-26 06:28:33</h3></center>\n\n\nRT @techpearce: Tuple and GXChain bid to build P2P data exchange marketplace https://t.co/RqRFFha1ze\n\n\n<hr>\n\n\n<center><h1> [techpearce](https://twitter.com/techpearce)</h1></center>\n<center><h3>2018-10-26 04:30:09</h3></center>\n\n\nTuple and GXChain bid to build P2P data exchange marketplace https://t.co/RqRFFha1ze\n\n\n<hr>\n\n\n<center><h1> [stocknewstimes](https://twitter.com/stocknewstimes)</h1></center>\n<center><h3>2018-10-26 02:29:24</h3></center>\n\n\nGXChain (GXS) Trading Down 1% Over Last 7 Days  https://t.co/fkvBpp8d6J\n\n\n<hr>\n\n\n<center><h1> [p2pmoneyshop](https://twitter.com/p2pmoneyshop)</h1></center>\n<center><h3>2018-10-25 21:06:56</h3></center>\n\n\nTuple and GXChain bid to build P2P data exchange marketplace https://t.co/ukMkj19XtI via @Finextra\n\n\n<hr>\n\n\n<center><h1> [_NXTalpha](https://twitter.com/_NXTalpha)</h1></center>\n<center><h3>2018-10-25 20:24:14</h3></center>\n\n\nThe #blockchain based peer-to-peer marketplace allows corporations and individuals to directly exchange their data… https://t.co/twqoeefL1f\n\n\n<hr>\n\n\n<center><h1> [_NXTalpha](https://twitter.com/_NXTalpha)</h1></center>\n<center><h3>2018-10-25 20:20:49</h3></center>\n\n\nData-centric #marketplace @tupletrade to partner with @gongxinbao https://t.co/XjhjrZ0RUX #ICO #kyc #AML #platform… https://t.co/xZEXeJ2Ya7\n\n\n<hr>\n\n\n<center><h1> [ladonsyl](https://twitter.com/ladonsyl)</h1></center>\n<center><h3>2018-10-25 17:36:18</h3></center>\n\n\nRT @gongxinbao: https://t.co/zEQe27gk2z is now live.\n\n#Blockchain #GXChain #Blockcity #Developers #Bitcoin\n\nhttps://t.co/Y7qxUI14M2\n\n\n<hr>\n\n\n<center><h1> [gongxinbao](https://twitter.com/gongxinbao)</h1></center>\n<center><h3>2018-10-25 17:35:41</h3></center>\n\n\nhttps://t.co/zEQe27gk2z is now live.\n\n#Blockchain #GXChain #Blockcity #Developers #Bitcoin\n\nhttps://t.co/Y7qxUI14M2\n\n\n<hr>\n\n\n<center>![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTwVEijeqq8pRK8Qrx1uM0Jh51aTbO2bNNXChLd5vjrVWA85Jy9)</center>\n',
#      'json_metadata': '{"tags": ["tothemoon"]}',
#      'parent_author': '',
#      'parent_permlink': 'tothemoon',
#      'permlink': 'what-people-thinks-about-gxchain-29-october-2018',
#      'title': 'What people thinks about GXChain\n29 October 2018'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T02:15:15',
#    'trx_id': '00f86b2281518224cba4691c71fa056fba1bc1ce',
#    'trx_in_block': 14,
#    'virtual_op': 0}],
#  [62874,
#   {'block': 27219799,
#    'op': ['transfer',
#     {'amount': '0.300 STEEM',
#      'from': 'misrori',
#      'memo': 'https://steemit.com/tothemoon/@misrori/what-people-thinks-about-gxchain-29-october-2018',
#      'to': 'postdoctor'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T02:15:27',
#    'trx_id': '02018207c6a4db6675d604711850c8209dd6777f',
#    'trx_in_block': 16,
#    'virtual_op': 0}],
#  [62875,
#   {'block': 27219819,
#    'op': ['comment',
#     {'author': 'badcontent',
#      'body': '**This user is on the @buildawhale blacklist for one or more of the following reasons:**\n\n* Spam\n* Plagiarism\n* Scam or Fraud\n\n',
#      'json_metadata': '',
#      'parent_author': 'misrori',
#      'parent_permlink': 'what-people-thinks-about-gxchain-29-october-2018',
#      'permlink': 're-what-people-thinks-about-gxchain-29-october-2018-20181029t021624',
#      'title': ''}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T02:16:27',
#    'trx_id': '4bf4464626900914e20c231cc467584fbf8f24b0',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [62876,
#   {'block': 27220048,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-digibyte-29-october-2018',
#      'voter': 'postdoctor',
#      'weight': 6667}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T02:27:54',
#    'trx_id': '109c20583596a81f6a0744e2b69fae3d0bf492df',
#    'trx_in_block': 11,
#    'virtual_op': 0}],
#  [62877,
#   {'block': 27220048,
#    'op': ['comment',
#     {'author': 'postdoctor',
#      'body': 'Wow greate article! \nThanks for using the @postdoctor service!\n',
#      'json_metadata': '{"app":"postpromoter/1.9.0"}',
#      'parent_author': 'misrori',
#      'parent_permlink': 'what-people-thinks-about-digibyte-29-october-2018',
#      'permlink': 're-misrori-what-people-thinks-about-digibyte-29-october-2018-20181029t022754473z',
#      'title': 're-misrori-what-people-thinks-about-digibyte-29-october-2018-20181029t022754473z'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T02:27:54',
#    'trx_id': '7be64163fc610bba83b9b80f7eedc34fd3d34184',
#    'trx_in_block': 12,
#    'virtual_op': 0}],
#  [62878,
#   {'block': 27220051,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-gxchain-29-october-2018',
#      'voter': 'postdoctor',
#      'weight': 3333}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T02:28:03',
#    'trx_id': '96ef44be5fd43a00f203ae7540e10859fecbac46',
#    'trx_in_block': 16,
#    'virtual_op': 0}],
#  [62879,
#   {'block': 27220058,
#    'op': ['comment',
#     {'author': 'postdoctor',
#      'body': 'Wow greate article! \nThanks for using the @postdoctor service!\n',
#      'json_metadata': '{"app":"postpromoter/1.9.0"}',
#      'parent_author': 'misrori',
#      'parent_permlink': 'what-people-thinks-about-gxchain-29-october-2018',
#      'permlink': 're-misrori-what-people-thinks-about-gxchain-29-october-2018-20181029t022824477z',
#      'title': 're-misrori-what-people-thinks-about-gxchain-29-october-2018-20181029t022824477z'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T02:28:24',
#    'trx_id': '6997544d2011c132e35e51cb05487ec6c661ec20',
#    'trx_in_block': 35,
#    'virtual_op': 0}],
#  [62880,
#   {'block': 27220219,
#    'op': ['transfer',
#     {'amount': '0.019 STEEM',
#      'from': 'edensgarden',
#      'memo': 'Round Earnings - 0.019 STEEM | Thank you!',
#      'to': 'misrori'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T02:36:27',
#    'trx_id': '18a2b8cade70cd215f4148838c231a043b59c5c2',
#    'trx_in_block': 12,
#    'virtual_op': 0}],
#  [62881,
#   {'block': 27220994,
#    'op': ['author_reward',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-theta-token-22-october-2018',
#      'sbd_payout': '0.031 SBD',
#      'steem_payout': '0.000 STEEM',
#      'vesting_payout': '80.685388 VESTS'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T03:15:15',
#    'trx_id': '0000000000000000000000000000000000000000',
#    'trx_in_block': 4294967295,
#    'virtual_op': 10}],
#  [62882,
#   {'block': 27220995,
#    'op': ['comment',
#     {'author': 'misrori',
#      'body': '<center><h1> Here you can see the latest 10 twitts about Waltonchain</h1></center>\n\n\n\n\n<center><h1> [cryptognition](https://twitter.com/cryptognition)</h1></center>\n<center><h3>2018-10-29 01:45:20</h3></center>\n\n\nRT @cryptofelixleon: First LG and now this. #waltonchain Iot + Blockchain solutions making some noise. Totally on \n\n$WTC #medicine #Supp…\n\n\n<hr>\n\n\n<center><h1> [robostopia](https://twitter.com/robostopia)</h1></center>\n<center><h3>2018-10-29 00:14:18</h3></center>\n\n\n $WTC may go up\n✅ BINANCE\n TRADINGVIEW: https://t.co/Tuf60qNpKa\n⛔ BITTREX\n COINMARKETCAP:… https://t.co/ByyCHEup8c\n\n\n<hr>\n\n\n<center><h1> [robostopia](https://twitter.com/robostopia)</h1></center>\n<center><h3>2018-10-28 21:09:14</h3></center>\n\n\n $WTC may go up\n✅ BINANCE\n TRADINGVIEW: https://t.co/Tuf60qNpKa\n⛔ BITTREX\n COINMARKETCAP:… https://t.co/zhTNhVMeHK\n\n\n<hr>\n\n\n<center><h1> [DusanSubic](https://twitter.com/DusanSubic)</h1></center>\n<center><h3>2018-10-28 20:58:08</h3></center>\n\n\nRT @vertaholic: How is @origin_trail under the radar ?\n• @gs1\n• Protocol \n• Tackling supply chain\n• 10M mcap only\n• Walmart winning award\n•…\n\n\n<hr>\n\n\n<center><h1> [Tilly__King_](https://twitter.com/Tilly__King_)</h1></center>\n<center><h3>2018-10-28 20:49:40</h3></center>\n\n\nRT @pgh72186: @CryptoTrader47 @Waltonchain I sold all my "Reverse swap miner payout" coins but will hold onto the node for now. Why? Not su…\n\n\n<hr>\n\n\n<center><h1> [UmbrelLumen](https://twitter.com/UmbrelLumen)</h1></center>\n<center><h3>2018-10-28 20:37:04</h3></center>\n\n\nRT @WaltonChainUK: Holy sh...... that’s some crazy volume for a $125m cap project. \nI guess the Koreans are buying one of the most legit Ch…\n\n\n<hr>\n\n\n<center><h1> [DeanofDAPS](https://twitter.com/DeanofDAPS)</h1></center>\n<center><h3>2018-10-28 19:50:47</h3></center>\n\n\n@RealJohnDough @Bitcoin @zilliqa @ElectracoinECA @Elastos_org @Waltonchain @nano @PolymathNetwork @vechainofficial… https://t.co/3NKyLigrcF\n\n\n<hr>\n\n\n<center><h1> [cryptofelixleon](https://twitter.com/cryptofelixleon)</h1></center>\n<center><h3>2018-10-28 19:32:55</h3></center>\n\n\nRT @WaltonChainUK: Holy sh...... that’s some crazy volume for a $125m cap project. \nI guess the Koreans are buying one of the most legit Ch…\n\n\n<hr>\n\n\n<center><h1> [LucasSm55170451](https://twitter.com/LucasSm55170451)</h1></center>\n<center><h3>2018-10-28 19:29:43</h3></center>\n\n\n@Waltonchain Why do I feel this is so much more solid than vechain..  Vechain has the hype but these guys delivering...\n\n\n<hr>\n\n\n<center><h1> [chipraider68](https://twitter.com/chipraider68)</h1></center>\n<center><h3>2018-10-28 19:16:00</h3></center>\n\n\n@igorGriffiths @Spacemancpu @Waltonchain I\'d say its prety much in the bag.\nWe need decentralised blockchain and Io… https://t.co/0VY9xVhPeL\n\n\n<hr>\n\n\n<center>![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTld2NiTa_oIxsC6o9ZdYf8hGrhZOJd5fLPzkzglzBEHhpl7B-0)</center>\n',
#      'json_metadata': '{"tags": ["video"]}',
#      'parent_author': '',
#      'parent_permlink': 'video',
#      'permlink': 'what-people-thinks-about-waltonchain-29-october-2018',
#      'title': 'What people thinks about Waltonchain\n29 October 2018'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T03:15:15',
#    'trx_id': '3d43484e3e6e340626a54ba8e735357a6f64de96',
#    'trx_in_block': 6,
#    'virtual_op': 0}],
#  [62883,
#   {'block': 27220999,
#    'op': ['transfer',
#     {'amount': '0.300 STEEM',
#      'from': 'misrori',
#      'memo': 'https://steemit.com/video/@misrori/what-people-thinks-about-waltonchain-29-october-2018',
#      'to': 'postdoctor'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T03:15:27',
#    'trx_id': '6ed0692695ca45bf5c7ec12596aaaab76d70b1fd',
#    'trx_in_block': 9,
#    'virtual_op': 0}],
#  [62884,
#   {'block': 27221018,
#    'op': ['comment',
#     {'author': 'badcontent',
#      'body': '**This user is on the @buildawhale blacklist for one or more of the following reasons:**\n\n* Spam\n* Plagiarism\n* Scam or Fraud\n\n',
#      'json_metadata': '',
#      'parent_author': 'misrori',
#      'parent_permlink': 'what-people-thinks-about-waltonchain-29-october-2018',
#      'permlink': 're-what-people-thinks-about-waltonchain-29-october-2018-20181029t031624',
#      'title': ''}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T03:16:24',
#    'trx_id': '95ef6e5a09cb66d0e7edf8e364c74d1db6ae5ef2',
#    'trx_in_block': 24,
#    'virtual_op': 0}],
#  [62885,
#   {'block': 27221309,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-waltonchain-29-october-2018',
#      'voter': 'hr1',
#      'weight': 8}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T03:30:57',
#    'trx_id': 'f6c6fead9d7b6912eddb02b38d0ee7bca250a5b0',
#    'trx_in_block': 8,
#    'virtual_op': 0}],
#  [62886,
#   {'block': 27222194,
#    'op': ['author_reward',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-nexo-22-october-2018',
#      'sbd_payout': '0.050 SBD',
#      'steem_payout': '0.000 STEEM',
#      'vesting_payout': '131.113463 VESTS'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T04:15:15',
#    'trx_id': '0000000000000000000000000000000000000000',
#    'trx_in_block': 4294967295,
#    'virtual_op': 6}],
#  [62887,
#   {'block': 27222195,
#    'op': ['comment',
#     {'author': 'misrori',
#      'body': '<center><h1> Here you can see the latest 10 twitts about ICON</h1></center>\n\n\n\n\n<center><h1> [on3dayiwrote](https://twitter.com/on3dayiwrote)</h1></center>\n<center><h3>2018-10-29 04:14:43</h3></center>\n\n\nRT @sugafull27: to themselves.\nIt’s a meaningful movie,\nAnd was a meaningful work.\nI’m thankful that they let me work together. #bts #방탄소년단…\n\n\n<hr>\n\n\n<center><h1> [theoreonextdoor](https://twitter.com/theoreonextdoor)</h1></center>\n<center><h3>2018-10-29 04:14:42</h3></center>\n\n\nRT @FUERTESKNIGHT: original Sabrina v underrated style icon https://t.co/WQPqFuKPcp\n\n\n<hr>\n\n\n<center><h1> [morganmccarthy4](https://twitter.com/morganmccarthy4)</h1></center>\n<center><h3>2018-10-29 04:14:41</h3></center>\n\n\nHi this year for Halloween I went as bisexual icon Shego from the hit series Kim Possible https://t.co/6zdDo0L2pd\n\n\n<hr>\n\n\n<center><h1> [musaratali](https://twitter.com/musaratali)</h1></center>\n<center><h3>2018-10-29 04:14:40</h3></center>\n\n\nRT @Fnews_english: #Khalifa_Sat, an #Emirati technological icon invades space\n.\n#UAE #KhalifaSat #Forsan_News https://t.co/raD5y7s9la\n\n\n<hr>\n\n\n<center><h1> [candyGalaxies](https://twitter.com/candyGalaxies)</h1></center>\n<center><h3>2018-10-29 04:14:39</h3></center>\n\n\nRT @DanArndtWrites: @HistoryisGayPod have you heard of this butch icon? https://t.co/B6xvBYWRrN\n\n\n<hr>\n\n\n<center><h1> [deadbeat_icon](https://twitter.com/deadbeat_icon)</h1></center>\n<center><h3>2018-10-29 04:14:32</h3></center>\n\n\nCan’t wait to cut my hair off tbh\n\n\n<hr>\n\n\n<center><h1> [paperfiregirls](https://twitter.com/paperfiregirls)</h1></center>\n<center><h3>2018-10-29 04:14:29</h3></center>\n\n\nRT @clonekin: Godtier: jinora’s light thirsty mako stan mana\nDemontier: uch*ha stan n*ruto icon eri\n\n\n<hr>\n\n\n<center><h1> [DavidNsingo](https://twitter.com/DavidNsingo)</h1></center>\n<center><h3>2018-10-29 04:14:17</h3></center>\n\n\nRT @DetroitBORG: The new shape of iPad confirmed by an iOS icon.  https://t.co/dPKhFRr22l via @9to5mac\n\n\n<hr>\n\n\n<center><h1> [thegr8_kate](https://twitter.com/thegr8_kate)</h1></center>\n<center><h3>2018-10-29 04:13:50</h3></center>\n\n\nRT @jxnnyr: You’re actually such an icon and the best drum major we have. No matter what anyone says that homecoming crown deserved… — that…\n\n\n<hr>\n\n\n<center><h1> [ConjugateThis](https://twitter.com/ConjugateThis)</h1></center>\n<center><h3>2018-10-29 04:13:40</h3></center>\n\n\nAngelina Jolie is a Boss.\n  Cleopatra is my hero.\n  Mahatma Gandhi is an icon.\n  Besides this business... I believe in astrology cuz I can.\n\n\n<hr>\n\n\n<center>![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQwnvoWEJSn2nFRqNhijN9h5Zv5-l4tP6iX5nbwz1uNIer_Kb78)</center>\n',
#      'json_metadata': '{"tags": ["success"]}',
#      'parent_author': '',
#      'parent_permlink': 'success',
#      'permlink': 'what-people-thinks-about-icon-29-october-2018',
#      'title': 'What people thinks about ICON\n29 October 2018'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T04:15:15',
#    'trx_id': '1e71af5f686f8622a5b984021748a45475934e7a',
#    'trx_in_block': 16,
#    'virtual_op': 0}],
#  [62888,
#   {'block': 27222199,
#    'op': ['transfer',
#     {'amount': '0.300 STEEM',
#      'from': 'misrori',
#      'memo': 'https://steemit.com/success/@misrori/what-people-thinks-about-icon-29-october-2018',
#      'to': 'postdoctor'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T04:15:27',
#    'trx_id': '17e452d14c9764cb243bc9c448e926deaae3ea8e',
#    'trx_in_block': 16,
#    'virtual_op': 0}],
#  [62889,
#   {'block': 27222218,
#    'op': ['comment',
#     {'author': 'badcontent',
#      'body': '**This user is on the @buildawhale blacklist for one or more of the following reasons:**\n\n* Spam\n* Plagiarism\n* Scam or Fraud\n\n',
#      'json_metadata': '',
#      'parent_author': 'misrori',
#      'parent_permlink': 'what-people-thinks-about-icon-29-october-2018',
#      'permlink': 're-what-people-thinks-about-icon-29-october-2018-20181029t041624',
#      'title': ''}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T04:16:24',
#    'trx_id': 'c908834f5fd8c92a3ee96b6757d8bfcfcb983303',
#    'trx_in_block': 10,
#    'virtual_op': 0}],
#  [62890,
#   {'block': 27222511,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-icon-29-october-2018',
#      'voter': 'hr1',
#      'weight': 8}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T04:31:03',
#    'trx_id': '47fa463e0736156f340ffb84e3be6bb83ec01d76',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [62891,
#   {'block': 27222921,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-waltonchain-29-october-2018',
#      'voter': 'postdoctor',
#      'weight': 5000}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T04:51:33',
#    'trx_id': '2bf9bc5f650cc95ef6b9ff6705aca0d6c485996e',
#    'trx_in_block': 8,
#    'virtual_op': 0}],
#  [62892,
#   {'block': 27222921,
#    'op': ['comment',
#     {'author': 'postdoctor',
#      'body': 'Wow greate article! \nThanks for using the @postdoctor service!\n',
#      'json_metadata': '{"app":"postpromoter/1.9.0"}',
#      'parent_author': 'misrori',
#      'parent_permlink': 'what-people-thinks-about-waltonchain-29-october-2018',
#      'permlink': 're-misrori-what-people-thinks-about-waltonchain-29-october-2018-20181029t045130923z',
#      'title': 're-misrori-what-people-thinks-about-waltonchain-29-october-2018-20181029t045130923z'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T04:51:33',
#    'trx_id': 'f6c46b47e2acc35fce5c5845e06355deaef26f90',
#    'trx_in_block': 10,
#    'virtual_op': 0}],
#  [62893,
#   {'block': 27222924,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-icon-29-october-2018',
#      'voter': 'postdoctor',
#      'weight': 5000}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T04:51:42',
#    'trx_id': '44becd68dba1425a42a232df78f6c2f8abadfbdc',
#    'trx_in_block': 9,
#    'virtual_op': 0}],
#  [62894,
#   {'block': 27222931,
#    'op': ['comment',
#     {'author': 'postdoctor',
#      'body': 'Wow greate article! \nThanks for using the @postdoctor service!\n',
#      'json_metadata': '{"app":"postpromoter/1.9.0"}',
#      'parent_author': 'misrori',
#      'parent_permlink': 'what-people-thinks-about-icon-29-october-2018',
#      'permlink': 're-misrori-what-people-thinks-about-icon-29-october-2018-20181029t045200929z',
#      'title': 're-misrori-what-people-thinks-about-icon-29-october-2018-20181029t045200929z'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T04:52:03',
#    'trx_id': '2c87ffe401296d03a4dbb27210c6d0cd07e39624',
#    'trx_in_block': 2,
#    'virtual_op': 0}],
#  [62895,
#   {'block': 27223394,
#    'op': ['author_reward',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-kucoin-shares-22-october-2018',
#      'sbd_payout': '0.047 SBD',
#      'steem_payout': '0.000 STEEM',
#      'vesting_payout': '123.044667 VESTS'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T05:15:15',
#    'trx_id': '0000000000000000000000000000000000000000',
#    'trx_in_block': 4294967295,
#    'virtual_op': 6}],
#  [62896,
#   {'block': 27223395,
#    'op': ['comment',
#     {'author': 'misrori',
#      'body': '<center><h1> Here you can see the latest 10 twitts about Stratis</h1></center>\n\n\n\n\n<center><h1> [RaviVerma170](https://twitter.com/RaviVerma170)</h1></center>\n<center><h3>2018-10-29 04:29:15</h3></center>\n\n\nRT @clint_network: A huge thank-you @bokobza @dangershony @NicolasDorier if you can retweet this #stratis #ticker and promised he will neve…\n\n\n<hr>\n\n\n<center><h1> [Kichi98981](https://twitter.com/Kichi98981)</h1></center>\n<center><h3>2018-10-29 04:17:27</h3></center>\n\n\nRT @stratisplatform: Stratis is now a certified Microsoft Partner: https://t.co/6jTChSs18e #blockchain #dotnet #development $STRAT https://…\n\n\n<hr>\n\n\n<center><h1> [shadowofthesun8](https://twitter.com/shadowofthesun8)</h1></center>\n<center><h3>2018-10-29 03:52:05</h3></center>\n\n\nStratis $STRAT price: $1.66 \n\nBinance registration is now OPEN for limited time!    \n\n➡️ https://t.co/3ZfflHvZmp… https://t.co/MzsqSIkIVn\n\n\n<hr>\n\n\n<center><h1> [HookemBears](https://twitter.com/HookemBears)</h1></center>\n<center><h3>2018-10-29 03:48:35</h3></center>\n\n\nRT @PolyCoins: This is precisely what Stratis should be all about. Seamlessly integrating into MSFT tools using familiar C# / Visual Studio…\n\n\n<hr>\n\n\n<center><h1> [AnalysisInChain](https://twitter.com/AnalysisInChain)</h1></center>\n<center><h3>2018-10-29 03:45:57</h3></center>\n\n\nSTRAT Current Price (USD): $ 1.67 Vol: STRAT 1.43 Change (24h): 0.86% $STRAT #stratis\n\n\n<hr>\n\n\n<center><h1> [3relacionamento](https://twitter.com/3relacionamento)</h1></center>\n<center><h3>2018-10-29 03:17:52</h3></center>\n\n\nMove your trading to the #1 crypto exchange today!\nBinance was NEVER hacked!\n\nhttps://t.co/i6djB0kBAi\n\n#Litecoin… https://t.co/IfMdQ0OkKX\n\n\n<hr>\n\n\n<center><h1> [Shashankrb07](https://twitter.com/Shashankrb07)</h1></center>\n<center><h3>2018-10-29 03:11:13</h3></center>\n\n\n@TheCryptoDog Stratis, brole out of 2 month accumulation period+retest on 1D\n\n\n<hr>\n\n\n<center><h1> [cryptoshark93](https://twitter.com/cryptoshark93)</h1></center>\n<center><h3>2018-10-29 03:02:53</h3></center>\n\n\nRT @Crimejoker: #Stratis Review – Building Blockchain for Enterprise by @chainbitsweb \n\n☄️Read more about it here:\n- https://t.co/kOJ1pb5Al…\n\n\n<hr>\n\n\n<center><h1> [Remi_Vladuceanu](https://twitter.com/Remi_Vladuceanu)</h1></center>\n<center><h3>2018-10-29 03:00:50</h3></center>\n\n\nStratis Price Eyes $2 Following Microsoft Certification Announcement\n➡️https://t.co/5cVOpcPxFY\n️\n▶️… https://t.co/F9It7riAyN\n\n\n<hr>\n\n\n<center><h1> [Janicextra](https://twitter.com/Janicextra)</h1></center>\n<center><h3>2018-10-29 02:54:20</h3></center>\n\n\nStratis $STRAT price: $1.65 \n\nWe checked! Binance registration is currently open    \n\n➡️ https://t.co/TxljZF6SZ1… https://t.co/waX9og8Vau\n\n\n<hr>\n\n\n<center>![](http://geekfence.com/wp-content/uploads/2017/05/bitcoin.jpg)</center>\n',
#      'json_metadata': '{"tags": ["tothemoon"]}',
#      'parent_author': '',
#      'parent_permlink': 'tothemoon',
#      'permlink': 'what-people-thinks-about-stratis-29-october-2018',
#      'title': 'What people thinks about Stratis\n29 October 2018'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T05:15:15',
#    'trx_id': '72b8e7385f921739f5abeaa51bb161c8dac03849',
#    'trx_in_block': 29,
#    'virtual_op': 0}],
#  [62897,
#   {'block': 27223399,
#    'op': ['transfer',
#     {'amount': '0.300 STEEM',
#      'from': 'misrori',
#      'memo': 'https://steemit.com/tothemoon/@misrori/what-people-thinks-about-stratis-29-october-2018',
#      'to': 'postdoctor'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T05:15:27',
#    'trx_id': '218c08bd944f5a7fb2142b85b611ecd69f776778',
#    'trx_in_block': 16,
#    'virtual_op': 0}],
#  [62898,
#   {'block': 27223418,
#    'op': ['comment',
#     {'author': 'badcontent',
#      'body': '**This user is on the @buildawhale blacklist for one or more of the following reasons:**\n\n* Spam\n* Plagiarism\n* Scam or Fraud\n\n',
#      'json_metadata': '',
#      'parent_author': 'misrori',
#      'parent_permlink': 'what-people-thinks-about-stratis-29-october-2018',
#      'permlink': 're-what-people-thinks-about-stratis-29-october-2018-20181029t051624',
#      'title': ''}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T05:16:24',
#    'trx_id': '44d2181eb2a9ba12ea6c0041f4c8c7d2966be42c',
#    'trx_in_block': 29,
#    'virtual_op': 0}],
#  [62899,
#   {'block': 27223427,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-stratis-29-october-2018',
#      'voter': 'luissanson',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T05:16:51',
#    'trx_id': 'ccb6033673620e0805062fc254f9907ca8d1cc03',
#    'trx_in_block': 13,
#    'virtual_op': 0}],
#  [62900,
#   {'block': 27223525,
#    'op': ['transfer',
#     {'amount': '0.001 SBD',
#      'from': 'allaz',
#      'memo': 'Promote your post. Your post will be min. 10  resteemed with over 13000  followers and min. 25  Upvote Different account (5000  STEEM POWER). Your post will be more popular and you will find new friends. Send 0.5 SBD or STEEM to @allaz ( URL as memo ) Service Active.',
#      'to': 'misrori'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T05:21:45',
#    'trx_id': 'd06fee1c9d3cc2fbeb486d5d099ec22c49dc637f',
#    'trx_in_block': 22,
#    'virtual_op': 0}],
#  [62901,
#   {'block': 27223697,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-stratis-29-october-2018',
#      'voter': 'hr1',
#      'weight': 8}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T05:30:21',
#    'trx_id': 'a2557017cd7378fbc65f97878e3799331f7e02cc',
#    'trx_in_block': 28,
#    'virtual_op': 0}],
#  [62902,
#   {'block': 27224594,
#    'op': ['author_reward',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-dentacoin-22-october-2018',
#      'sbd_payout': '0.074 SBD',
#      'steem_payout': '0.000 STEEM',
#      'vesting_payout': '191.626512 VESTS'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T06:15:15',
#    'trx_id': '0000000000000000000000000000000000000000',
#    'trx_in_block': 4294967295,
#    'virtual_op': 5}],
#  [62903,
#   {'block': 27224596,
#    'op': ['comment',
#     {'author': 'misrori',
#      'body': '<center><h1> Here you can see the latest 10 twitts about Veritaseum</h1></center>\n\n\n\n\n<center><h1> [robostopia](https://twitter.com/robostopia)</h1></center>\n<center><h3>2018-10-29 06:09:35</h3></center>\n\n\n $VERI may go up\n⛔ BINANCE\n COINMARKETCAP: https://t.co/kfX7aFaXkV\n⛔ BITTREX\n COINMARKETCAP:… https://t.co/kI6Sba8PrM\n\n\n<hr>\n\n\n<center><h1> [mauriciowolf13](https://twitter.com/mauriciowolf13)</h1></center>\n<center><h3>2018-10-29 02:23:03</h3></center>\n\n\nRT @ReggieMiddleton: Doubted my proclamations of a Pan-African Economic Token? We cryptographically unite the economies of Nigeria &amp; Uganda…\n\n\n<hr>\n\n\n<center><h1> [robostopia](https://twitter.com/robostopia)</h1></center>\n<center><h3>2018-10-29 00:24:30</h3></center>\n\n\n $VERI may go up\n⛔ BINANCE\n COINMARKETCAP: https://t.co/kfX7aFaXkV\n⛔ BITTREX\n COINMARKETCAP:… https://t.co/kdTCXLgR4f\n\n\n<hr>\n\n\n<center><h1> [BillTaylor45](https://twitter.com/BillTaylor45)</h1></center>\n<center><h3>2018-10-28 23:51:52</h3></center>\n\n\n@clif_high Negative Will Robinson,  the fucktards are falling away,  the hard core are still here. Veritaseum is rebounding!\n\n\n<hr>\n\n\n<center><h1> [Johnbenitezjr](https://twitter.com/Johnbenitezjr)</h1></center>\n<center><h3>2018-10-28 23:45:06</h3></center>\n\n\nThe price of Veritaseum is $45.65! https://t.co/qvHfAMlaZI #bitcoin #cnbc #bloomberg #thestreet\n\n\n<hr>\n\n\n<center><h1> [Peter_TheHoward](https://twitter.com/Peter_TheHoward)</h1></center>\n<center><h3>2018-10-28 22:02:29</h3></center>\n\n\nRT @AQuFQHI4WgEkG3A: CryptoCoins Comment on Veritaseum Price Tackles $45 Resistance With Relative Ease by Sara Conner: This coin will chang…\n\n\n<hr>\n\n\n<center><h1> [WellsDiggs](https://twitter.com/WellsDiggs)</h1></center>\n<center><h3>2018-10-28 17:44:32</h3></center>\n\n\n@AdrianaCohen16 @kanyewest @RealCandaceO @TPUSA @GOP @GOPChairwoman @realDonaldTrump @FoxBusiness Buy and use Bitco… https://t.co/ptqlZNCaeb\n\n\n<hr>\n\n\n<center><h1> [gadgetheros](https://twitter.com/gadgetheros)</h1></center>\n<center><h3>2018-10-28 15:26:39</h3></center>\n\n\nRT @crypto_alert: Top 3! 1/3 - #Veritaseum #VERI $VERI\n\nLast 24h - 10.4%\nMarketCap - 83734606.0€\n41.11398€\n0.00724฿\n\n\n<hr>\n\n\n<center><h1> [robostopia](https://twitter.com/robostopia)</h1></center>\n<center><h3>2018-10-28 15:20:25</h3></center>\n\n\n $VERI may go up\n⛔ BINANCE\n COINMARKETCAP: https://t.co/kfX7aFaXkV\n⛔ BITTREX\n COINMARKETCAP:… https://t.co/TY9PQGGiHg\n\n\n<hr>\n\n\n<center><h1> [BtcCrypto_News](https://twitter.com/BtcCrypto_News)</h1></center>\n<center><h3>2018-10-28 12:36:48</h3></center>\n\n\nRT @BCN_Education: I liked a @YouTube video https://t.co/0Y3ikrKAg0 Veritaseum Q&amp;A, 10/25/18\n\n\n<hr>\n\n\n<center>![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQb51inZXD7B0VsXlUT7AXfC6tq5mc0sybpmhnm8b3IVrvhfcnKCQ)</center>\n',
#      'json_metadata': '{"tags": ["youtube"]}',
#      'parent_author': '',
#      'parent_permlink': 'youtube',
#      'permlink': 'what-people-thinks-about-veritaseum-29-october-2018',
#      'title': 'What people thinks about Veritaseum\n29 October 2018'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T06:15:18',
#    'trx_id': '629194ec51b2e83587969ef32a9ef33fb1cd8d2e',
#    'trx_in_block': 11,
#    'virtual_op': 0}],
#  [62904,
#   {'block': 27224600,
#    'op': ['transfer',
#     {'amount': '0.300 STEEM',
#      'from': 'misrori',
#      'memo': 'https://steemit.com/youtube/@misrori/what-people-thinks-about-veritaseum-29-october-2018',
#      'to': 'postdoctor'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T06:15:30',
#    'trx_id': 'c45ea5ac6e8ac2e2fbbd2f5bc617e17b039ffa7c',
#    'trx_in_block': 4,
#    'virtual_op': 0}],
#  [62905,
#   {'block': 27224618,
#    'op': ['comment',
#     {'author': 'badcontent',
#      'body': '**This user is on the @buildawhale blacklist for one or more of the following reasons:**\n\n* Spam\n* Plagiarism\n* Scam or Fraud\n\n',
#      'json_metadata': '',
#      'parent_author': 'misrori',
#      'parent_permlink': 'what-people-thinks-about-veritaseum-29-october-2018',
#      'permlink': 're-what-people-thinks-about-veritaseum-29-october-2018-20181029t061624',
#      'title': ''}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T06:16:24',
#    'trx_id': '8d05cff4fb1eb501226017586a9ec965c61eadaa',
#    'trx_in_block': 27,
#    'virtual_op': 0}],
#  [62906,
#   {'block': 27224822,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-veritaseum-29-october-2018',
#      'voter': 'umich',
#      'weight': 1200}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T06:26:36',
#    'trx_id': '6a4cdac08955d86226e410027dd572cf736b3e5a',
#    'trx_in_block': 1,
#    'virtual_op': 0}],
#  [62907,
#   {'block': 27224823,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-veritaseum-29-october-2018',
#      'voter': 'cjd',
#      'weight': 1200}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T06:26:39',
#    'trx_id': '2e04c1b9c11c9b04baaee142ce6a258d293a3b68',
#    'trx_in_block': 19,
#    'virtual_op': 0}],
#  [62908,
#   {'block': 27224823,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-veritaseum-29-october-2018',
#      'voter': 'guangzhoulife',
#      'weight': 1200}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T06:26:39',
#    'trx_id': '9e87a3b52a1d5e4f78f90e3a922e66a774afe3b9',
#    'trx_in_block': 20,
#    'virtual_op': 0}],
#  [62909,
#   {'block': 27224823,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-veritaseum-29-october-2018',
#      'voter': 'voyagesofcarla2',
#      'weight': 600}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T06:26:39',
#    'trx_id': '98e6ad0dfb1ec497d824a7fddea9135608230685',
#    'trx_in_block': 21,
#    'virtual_op': 0}],
#  [62910,
#   {'block': 27224901,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-veritaseum-29-october-2018',
#      'voter': 'hr1',
#      'weight': 8}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T06:30:33',
#    'trx_id': '33fc53cf0edeb37b523c933ff51d7d5c58ef00d5',
#    'trx_in_block': 24,
#    'virtual_op': 0}],
#  [62911,
#   {'block': 27225223,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-veritaseum-29-october-2018',
#      'voter': 'idontgnu',
#      'weight': 1200}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T06:46:42',
#    'trx_id': 'da5e83ccaf1f6800dea0057df8df5a9c71e63e9b',
#    'trx_in_block': 36,
#    'virtual_op': 0}],
#  [62912,
#   {'block': 27225312,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-veritaseum-29-october-2018',
#      'voter': 'leduc1984',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T06:51:09',
#    'trx_id': '6beab32b29a90bc116efd14ec6708865358a26ac',
#    'trx_in_block': 2,
#    'virtual_op': 0}],
#  [62913,
#   {'block': 27225778,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-stratis-29-october-2018',
#      'voter': 'postdoctor',
#      'weight': 5000}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T07:14:27',
#    'trx_id': '7a9b9a49efd8ffa2c513a5a1da8844690f3bd7b0',
#    'trx_in_block': 19,
#    'virtual_op': 0}],
#  [62914,
#   {'block': 27225779,
#    'op': ['comment',
#     {'author': 'postdoctor',
#      'body': 'Wow greate article! \nThanks for using the @postdoctor service!\n',
#      'json_metadata': '{"app":"postpromoter/1.9.0"}',
#      'parent_author': 'misrori',
#      'parent_permlink': 'what-people-thinks-about-stratis-29-october-2018',
#      'permlink': 're-misrori-what-people-thinks-about-stratis-29-october-2018-20181029t071427523z',
#      'title': 're-misrori-what-people-thinks-about-stratis-29-october-2018-20181029t071427523z'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T07:14:30',
#    'trx_id': '5576e6ea59ceb63f9a20dfbffc5c32c0f2427015',
#    'trx_in_block': 3,
#    'virtual_op': 0}],
#  [62915,
#   {'block': 27225781,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-veritaseum-29-october-2018',
#      'voter': 'postdoctor',
#      'weight': 5000}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T07:14:36',
#    'trx_id': '06ae2ed95c264aa87324ea360b499b3b83483124',
#    'trx_in_block': 9,
#    'virtual_op': 0}],
#  [62916,
#   {'block': 27225788,
#    'op': ['comment',
#     {'author': 'postdoctor',
#      'body': 'Wow greate article! \nThanks for using the @postdoctor service!\n',
#      'json_metadata': '{"app":"postpromoter/1.9.0"}',
#      'parent_author': 'misrori',
#      'parent_permlink': 'what-people-thinks-about-veritaseum-29-october-2018',
#      'permlink': 're-misrori-what-people-thinks-about-veritaseum-29-october-2018-20181029t071457533z',
#      'title': 're-misrori-what-people-thinks-about-veritaseum-29-october-2018-20181029t071457533z'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T07:14:57',
#    'trx_id': 'e12dc391fa3e5f274f1cf64eb0ea0ed98688cb29',
#    'trx_in_block': 30,
#    'virtual_op': 0}],
#  [62917,
#   {'block': 27225794,
#    'op': ['comment',
#     {'author': 'misrori',
#      'body': '<center><h1> Here you can see the latest 10 twitts about Ontology</h1></center>\n\n\n\n\n<center><h1> [SeqComplete](https://twitter.com/SeqComplete)</h1></center>\n<center><h3>2018-10-29 07:03:55</h3></center>\n\n\n#BioIT #BioInformatics How do transcript-level gene ontology https://t.co/2M8MUCDWlW\n\n\n<hr>\n\n\n<center><h1> [SpokkzOfficial](https://twitter.com/SpokkzOfficial)</h1></center>\n<center><h3>2018-10-29 07:00:01</h3></center>\n\n\nContent creators working with Spokkz will enjoy the security of tokenised pre-funding, viewership profits and an ap… https://t.co/8CtgrV8eTG\n\n\n<hr>\n\n\n<center><h1> [Seekandshare](https://twitter.com/Seekandshare)</h1></center>\n<center><h3>2018-10-29 06:59:31</h3></center>\n\n\nNow is time to make your money work for you! Aren´t you tired of working extra hours to get more income?  Learn mor… https://t.co/a2QiVXG3OX\n\n\n<hr>\n\n\n<center><h1> [oddgems](https://twitter.com/oddgems)</h1></center>\n<center><h3>2018-10-29 06:57:29</h3></center>\n\n\nIf you think $TOMO and $UPP wouldn\'t do an $ICX, go checkout #hashed capital portfolio. The same venture backing… https://t.co/RJkVdQMDEz\n\n\n<hr>\n\n\n<center><h1> [IgnacioEnriquez](https://twitter.com/IgnacioEnriquez)</h1></center>\n<center><h3>2018-10-29 06:03:38</h3></center>\n\n\n"Elements for an Ontology of Care in the Field of Artificial Intelligence." https://t.co/EFy9FAnjx5 #pubmed #feedly\n\n\n<hr>\n\n\n<center><h1> [Ontology_](https://twitter.com/Ontology_)</h1></center>\n<center><h3>2018-10-29 05:51:45</h3></center>\n\n\nA conceptualization is an abstract, simplified view of the world that we wish to represent for some purpose. Every… https://t.co/M6vP265Msn\n\n\n<hr>\n\n\n<center><h1> [ByrzikD](https://twitter.com/ByrzikD)</h1></center>\n<center><h3>2018-10-29 05:45:32</h3></center>\n\n\nRT @SpokkzOfficial: Spokkz is regaining the rights and access that stakeholders should have to engage in the media space. https://t.co/t5dx…\n\n\n<hr>\n\n\n<center><h1> [ribowo_ja](https://twitter.com/ribowo_ja)</h1></center>\n<center><h3>2018-10-29 05:24:59</h3></center>\n\n\nRT @SpokkzOfficial: Spokkz is regaining the rights and access that stakeholders should have to engage in the media space. https://t.co/t5dx…\n\n\n<hr>\n\n\n<center><h1> [Ontology_](https://twitter.com/Ontology_)</h1></center>\n<center><h3>2018-10-29 05:21:44</h3></center>\n\n\nOntology seeks to provide a definitive and exhaustive classification of entities in all spheres of being.-Barry Smith #Ontology #semantic\n\n\n<hr>\n\n\n<center><h1> [3relacionamento](https://twitter.com/3relacionamento)</h1></center>\n<center><h3>2018-10-29 05:21:34</h3></center>\n\n\nMove your trading to the #1 crypto exchange today!\nBinance was NEVER hacked!\n\nhttps://t.co/i6djB0kBAi\n\n#Litecoin… https://t.co/j0Vy2Fv2LL\n\n\n<hr>\n\n\n<center>![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSodBycdldXvibTfczWP_WoLqNOTUwzTgp6Uzfvop_KBn-ql60g1Q)</center>\n',
#      'json_metadata': '{"tags": ["tothemoon"]}',
#      'parent_author': '',
#      'parent_permlink': 'tothemoon',
#      'permlink': 'what-people-thinks-about-ontology-29-october-2018',
#      'title': 'What people thinks about Ontology\n29 October 2018'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T07:15:15',
#    'trx_id': 'fa146edca8816391bbb1bf158eafffb3ed505747',
#    'trx_in_block': 29,
#    'virtual_op': 0}],
#  [62918,
#   {'block': 27225798,
#    'op': ['transfer',
#     {'amount': '0.300 STEEM',
#      'from': 'misrori',
#      'memo': 'https://steemit.com/tothemoon/@misrori/what-people-thinks-about-ontology-29-october-2018',
#      'to': 'postdoctor'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T07:15:27',
#    'trx_id': '2c84e21f609323b703b0cfc64d86d7092d1cfe1d',
#    'trx_in_block': 19,
#    'virtual_op': 0}],
#  [62919,
#   {'block': 27225818,
#    'op': ['comment',
#     {'author': 'badcontent',
#      'body': '**This user is on the @buildawhale blacklist for one or more of the following reasons:**\n\n* Spam\n* Plagiarism\n* Scam or Fraud\n\n',
#      'json_metadata': '',
#      'parent_author': 'misrori',
#      'parent_permlink': 'what-people-thinks-about-ontology-29-october-2018',
#      'permlink': 're-what-people-thinks-about-ontology-29-october-2018-20181029t071624',
#      'title': ''}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T07:16:27',
#    'trx_id': '7b1786ae7382c60d14daf688d1ba849a3b684f71',
#    'trx_in_block': 4,
#    'virtual_op': 0}],
#  [62920,
#   {'block': 27226063,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-ontology-29-october-2018',
#      'voter': 'umich',
#      'weight': 1200}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T07:28:42',
#    'trx_id': 'ef416175dbe29701e8457e18bc15e7e3cb7f7938',
#    'trx_in_block': 8,
#    'virtual_op': 0}],
#  [62921,
#   {'block': 27226064,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-ontology-29-october-2018',
#      'voter': 'geocities',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T07:28:45',
#    'trx_id': '21f6700c3d928502dfd00b3dea107d694d7e5433',
#    'trx_in_block': 12,
#    'virtual_op': 0}],
#  [62922,
#   {'block': 27226064,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-ontology-29-october-2018',
#      'voter': 'hbosteem',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T07:28:45',
#    'trx_id': 'c9a27c50d619b5a533b7c019d55f51c9cb82ec46',
#    'trx_in_block': 14,
#    'virtual_op': 0}],
#  [62923,
#   {'block': 27226064,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-ontology-29-october-2018',
#      'voter': 'emirfirlar',
#      'weight': 600}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T07:28:45',
#    'trx_id': '206ff4639dcab6576c4a7d86ad69f09e6c6f71c5',
#    'trx_in_block': 16,
#    'virtual_op': 0}],
#  [62924,
#   {'block': 27226064,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-ontology-29-october-2018',
#      'voter': 'cjd',
#      'weight': 1200}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T07:28:45',
#    'trx_id': '616bd375e39f0b021a85a231be992bc7838eff11',
#    'trx_in_block': 20,
#    'virtual_op': 0}],
#  [62925,
#   {'block': 27226064,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-ontology-29-october-2018',
#      'voter': 'guangzhoulife',
#      'weight': 1200}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T07:28:45',
#    'trx_id': 'c66258cc100659bc68981df731813cb4434a5593',
#    'trx_in_block': 21,
#    'virtual_op': 0}],
#  [62926,
#   {'block': 27226064,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-ontology-29-october-2018',
#      'voter': 'voyagesofcarla2',
#      'weight': 600}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T07:28:45',
#    'trx_id': '1f407483942342219ae023c6a3e710c504b50db4',
#    'trx_in_block': 22,
#    'virtual_op': 0}],
#  [62927,
#   {'block': 27226093,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-ontology-29-october-2018',
#      'voter': 'hr1',
#      'weight': 8}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T07:30:12',
#    'trx_id': '454408cad9bddd40a96a01b7736b229fcf67b462',
#    'trx_in_block': 5,
#    'virtual_op': 0}],
#  [62928,
#   {'block': 27226206,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-ontology-29-october-2018',
#      'voter': 'plgonzalezrx8',
#      'weight': 1200}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T07:35:51',
#    'trx_id': '21fe360aa44bc9578a98d3951b0da07af4442e05',
#    'trx_in_block': 21,
#    'virtual_op': 0}],
#  [62929,
#   {'block': 27226465,
#    'op': ['transfer',
#     {'amount': '0.049 STEEM',
#      'from': 'edensgarden',
#      'memo': 'Round Earnings - 0.049 STEEM | Thank you!',
#      'to': 'misrori'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T07:48:51',
#    'trx_id': 'fa8c9b7cf64e4c11a28005af19b1abf84de01c34',
#    'trx_in_block': 15,
#    'virtual_op': 0}],
#  [62930,
#   {'block': 27226466,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-ontology-29-october-2018',
#      'voter': 'idontgnu',
#      'weight': 1200}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T07:48:54',
#    'trx_id': 'dac9d485177373ed60707c702e4bf3458579c013',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [62931,
#   {'block': 27226993,
#    'op': ['comment',
#     {'author': 'misrori',
#      'body': "<center><h1> Here you can see the latest 10 twitts about Ardor</h1></center>\n\n\n\n\n<center><h1> [MrV_777](https://twitter.com/MrV_777)</h1></center>\n<center><h3>2018-10-29 08:11:26</h3></center>\n\n\nRT @AvdiuSazan: #Ardor unique three layer architecture:\n-Parent/Child POS #blockchain\n-Built-in contracts with messages, properties, storag…\n\n\n<hr>\n\n\n<center><h1> [carthag90184426](https://twitter.com/carthag90184426)</h1></center>\n<center><h3>2018-10-29 08:09:33</h3></center>\n\n\nRT @AvdiuSazan: #BlockchainAsAService refers to the cloud-based services offered by big tech giants #IBMCloud, #Microsoft, #HPE, #SAP, #AWS…\n\n\n<hr>\n\n\n<center><h1> [AvdiuSazan](https://twitter.com/AvdiuSazan)</h1></center>\n<center><h3>2018-10-29 07:58:38</h3></center>\n\n\n#BlockchainAsAService refers to the cloud-based services offered by big tech giants #IBMCloud, #Microsoft, #HPE,… https://t.co/IHk5dWfydW\n\n\n<hr>\n\n\n<center><h1> [mjrko](https://twitter.com/mjrko)</h1></center>\n<center><h3>2018-10-29 07:41:59</h3></center>\n\n\nRT @Malnemark1: @CryptoDemetrius @brucefenton I don't think this is the point here, you need to use multiple contracts on their nodes and v…\n\n\n<hr>\n\n\n<center><h1> [mjrko](https://twitter.com/mjrko)</h1></center>\n<center><h3>2018-10-29 07:41:01</h3></center>\n\n\nRT @CryptoDemetrius: @brucefenton The answer is lightweight contracts. Stateless, 2 step deployment. Check it out on the #Ardor platform's…\n\n\n<hr>\n\n\n<center><h1> [AvdiuSazan](https://twitter.com/AvdiuSazan)</h1></center>\n<center><h3>2018-10-29 07:37:59</h3></center>\n\n\n#Ardor unique three layer architecture:\n-Parent/Child POS #blockchain\n-Built-in contracts with messages, properties… https://t.co/0HxMw4trA2\n\n\n<hr>\n\n\n<center><h1> [AvdiuSazan](https://twitter.com/AvdiuSazan)</h1></center>\n<center><h3>2018-10-29 07:29:40</h3></center>\n\n\n#Ardor lightweight contracts are stored on the blockchain but their execution is not part of the blockchain consens… https://t.co/mWcmSR66Ak\n\n\n<hr>\n\n\n<center><h1> [vishaldilse2](https://twitter.com/vishaldilse2)</h1></center>\n<center><h3>2018-10-29 07:22:45</h3></center>\n\n\nRT @RomancingThFood: I tried this Khalibali 56inch thali from Ardor 2.1 And it was so GOOD! Weight is about 55kgs, 31+ dishes and can be sh…\n\n\n<hr>\n\n\n<center><h1> [Manchester_Hous](https://twitter.com/Manchester_Hous)</h1></center>\n<center><h3>2018-10-29 07:19:18</h3></center>\n\n\nAccessorize your bed with this quilted #valance by #Ardor featuring a  clean, solid-colour design that will look gr… https://t.co/J2D0Y3NTJQ\n\n\n<hr>\n\n\n<center><h1> [jesse_hume](https://twitter.com/jesse_hume)</h1></center>\n<center><h3>2018-10-29 07:05:34</h3></center>\n\n\n@julia_jenkins I have a great Ardor for synonyms. Not sure if it's as great as your Zeal for food though, or your F… https://t.co/PL8pvFmTQD\n\n\n<hr>\n\n\n<center>![](http://geekfence.com/wp-content/uploads/2017/05/bitcoin.jpg)</center>\n",
#      'json_metadata': '{"tags": ["success"]}',
#      'parent_author': '',
#      'parent_permlink': 'success',
#      'permlink': 'what-people-thinks-about-ardor-29-october-2018',
#      'title': 'What people thinks about Ardor\n29 October 2018'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T08:15:15',
#    'trx_id': 'ec8082b5c53d553e4d46833ac4adeb149374d6c7',
#    'trx_in_block': 27,
#    'virtual_op': 0}],
#  [62932,
#   {'block': 27226997,
#    'op': ['transfer',
#     {'amount': '0.300 STEEM',
#      'from': 'misrori',
#      'memo': 'https://steemit.com/success/@misrori/what-people-thinks-about-ardor-29-october-2018',
#      'to': 'postdoctor'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-29T08:15:27',
#    'trx_id': '14875bb19c38143ee485aaaa25342ff90f75143e',
#    'trx_in_block': 19,
#    'virtual_op': 0}],
#  [62933,
#   {'block': 27227025,
#    'op': ['comment',
#     {'author': 'badcontent',
# ...
#    'trx_id': '0000000000000000000000000000000000000000',
#    'trx_in_block': 4294967295,
#    'virtual_op': 4}],
#  [63348,
#   {'block': 27288149,
#    'op': ['transfer',
#     {'amount': '0.300 STEEM',
#      'from': 'misrori',
#      'memo': 'https://steemit.com/tothemoon/@misrori/what-people-thinks-about-bytecoin-31-october-2018',
#      'to': 'postdoctor'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-31T11:15:27',
#    'trx_id': '1801ba780d2ac7ecddbf808955a2ffb36f9fbd3d',
#    'trx_in_block': 20,
#    'virtual_op': 0}],
#  [63349,
#   {'block': 27288168,
#    'op': ['comment',
#     {'author': 'badcontent',
#      'body': '**This user is on the @buildawhale blacklist for one or more of the following reasons:**\n\n* Spam\n* Plagiarism\n* Scam or Fraud\n\n',
#      'json_metadata': '',
#      'parent_author': 'misrori',
#      'parent_permlink': 'what-people-thinks-about-bytecoin-31-october-2018',
#      'permlink': 're-what-people-thinks-about-bytecoin-31-october-2018-20181031t111624',
#      'title': ''}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-31T11:16:24',
#    'trx_id': '819f27e3d7688fa209dd5bb63747758039b54897',
#    'trx_in_block': 18,
#    'virtual_op': 0}],
#  [63350,
#   {'block': 27288221,
#    'op': ['transfer',
#     {'amount': '0.001 SBD',
#      'from': 'resteembot',
#      'memo': 'A gift',
#      'to': 'misrori'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-31T11:19:03',
#    'trx_id': '601fc8e027ee26142198ad8a9a50ce5d3c824aea',
#    'trx_in_block': 27,
#    'virtual_op': 0}],
#  [63351,
#   {'block': 27288418,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-bytecoin-31-october-2018',
#      'voter': 'beco132',
#      'weight': 170}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-31T11:28:54',
#    'trx_id': 'aedeff5e35f0d06fc0595bcc7942a28c2a70692c',
#    'trx_in_block': 19,
#    'virtual_op': 0}],
#  [63352,
#   {'block': 27288447,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-bytecoin-31-october-2018',
#      'voter': 'hr1',
#      'weight': 8}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-31T11:30:21',
#    'trx_id': 'c9a3621842ae0a0694ad83f2c9086c9d329bd262',
#    'trx_in_block': 49,
#    'virtual_op': 0}],
#  [63353,
#   {'block': 27288915,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-eternal-token-31-october-2018',
#      'voter': 'postdoctor',
#      'weight': 5000}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-31T11:53:45',
#    'trx_id': 'eb29cf383512b18deb8977e91c6303464c7cb352',
#    'trx_in_block': 24,
#    'virtual_op': 0}],
#  [63354,
#   {'block': 27288915,
#    'op': ['comment',
#     {'author': 'postdoctor',
#      'body': 'Wow greate article! \nThanks for using the @postdoctor service!\n',
#      'json_metadata': '{"app":"postpromoter/1.9.0"}',
#      'parent_author': 'misrori',
#      'parent_permlink': 'what-people-thinks-about-eternal-token-31-october-2018',
#      'permlink': 're-misrori-what-people-thinks-about-eternal-token-31-october-2018-20181031t115344436z',
#      'title': 're-misrori-what-people-thinks-about-eternal-token-31-october-2018-20181031t115344436z'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-31T11:53:45',
#    'trx_id': 'ec13253c44576f22e8f604bad998f3532e58e3b5',
#    'trx_in_block': 26,
#    'virtual_op': 0}],
#  [63355,
#   {'block': 27288918,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-bytecoin-31-october-2018',
#      'voter': 'postdoctor',
#      'weight': 5000}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-31T11:53:54',
#    'trx_id': 'd56cf50ee44ca50aa665e9f20f5990cd6be98817',
#    'trx_in_block': 21,
#    'virtual_op': 0}],
#  [63356,
#   {'block': 27288925,
#    'op': ['comment',
#     {'author': 'postdoctor',
#      'body': 'Wow greate article! \nThanks for using the @postdoctor service!\n',
#      'json_metadata': '{"app":"postpromoter/1.9.0"}',
#      'parent_author': 'misrori',
#      'parent_permlink': 'what-people-thinks-about-bytecoin-31-october-2018',
#      'permlink': 're-misrori-what-people-thinks-about-bytecoin-31-october-2018-20181031t115414444z',
#      'title': 're-misrori-what-people-thinks-about-bytecoin-31-october-2018-20181031t115414444z'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-31T11:54:15',
#    'trx_id': '5feb5a51c42827254fafb7f1b041a72def236f16',
#    'trx_in_block': 22,
#    'virtual_op': 0}],
#  [63357,
#   {'block': 27289344,
#    'op': ['author_reward',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-mobilego-24-october-2018',
#      'sbd_payout': '0.047 SBD',
#      'steem_payout': '0.000 STEEM',
#      'vesting_payout': '125.046432 VESTS'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-31T12:15:15',
#    'trx_id': '0000000000000000000000000000000000000000',
#    'trx_in_block': 4294967295,
#    'virtual_op': 17}],
#  [63358,
#   {'block': 27289345,
#    'op': ['comment',
#     {'author': 'misrori',
#      'body': "<center><h1> Here you can see the latest 10 twitts about Nano</h1></center>\n\n\n\n\n<center><h1> [JuiceP](https://twitter.com/JuiceP)</h1></center>\n<center><h3>2018-10-31 12:14:46</h3></center>\n\n\n10% Discount for 6 months on BITMEX trading fees wtih my Link!!\n\nClick here: https://t.co/yExpIXPvzq\xa0    \n\n$BAT… https://t.co/dBDgKqgCw4\n\n\n<hr>\n\n\n<center><h1> [IMDEA_Nano](https://twitter.com/IMDEA_Nano)</h1></center>\n<center><h3>2018-10-31 12:14:43</h3></center>\n\n\nRT @3M_Lab: Our work describing  the dynamics of individual molecular shuttles with optical tweezers is out! @NatureComms\nA truly interdisc…\n\n\n<hr>\n\n\n<center><h1> [M_C_Crocker](https://twitter.com/M_C_Crocker)</h1></center>\n<center><h3>2018-10-31 12:14:15</h3></center>\n\n\nWith the panic some are feeling about NaNo and the fact that it starts tomorrow I'm going to push this blog out onc… https://t.co/6KRDKLOluF\n\n\n<hr>\n\n\n<center><h1> [Werhe1981](https://twitter.com/Werhe1981)</h1></center>\n<center><h3>2018-10-31 12:14:09</h3></center>\n\n\nWhy did NEO launch 2 new token on their network – CNEO and CGAS?\n\nhttps://t.co/Kp1tpeKrVa\n\n$NANO $QSP $ICN $BNB… https://t.co/bqpsnjp2uR\n\n\n<hr>\n\n\n<center><h1> [crypto_better](https://twitter.com/crypto_better)</h1></center>\n<center><h3>2018-10-31 12:14:08</h3></center>\n\n\nMake money trading on Binance - The best Crypto Exchange\n\nClick here: https://t.co/p8zl1Z9I0R\xa0  \n\n$BTC $ETH $EOS… https://t.co/n2w88dhnYg\n\n\n<hr>\n\n\n<center><h1> [h2020gracious](https://twitter.com/h2020gracious)</h1></center>\n<center><h3>2018-10-31 12:13:58</h3></center>\n\n\nSave the dates 25-29 March 2019 for a #nanosafety #nanomedicine training school: Cutting Edge Approaches for the Ri… https://t.co/tfFwQPMUGf\n\n\n<hr>\n\n\n<center><h1> [AychaRydha](https://twitter.com/AychaRydha)</h1></center>\n<center><h3>2018-10-31 12:13:56</h3></center>\n\n\nMake money trading on Binance - The best Crypto Exchange\n\nClick here: https://t.co/F3nYKpKraN  \n\n$BTC $ETH $EOS… https://t.co/SLBWcpNkj4\n\n\n<hr>\n\n\n<center><h1> [nano_napy](https://twitter.com/nano_napy)</h1></center>\n<center><h3>2018-10-31 12:13:50</h3></center>\n\n\nlove\n\n\n<hr>\n\n\n<center><h1> [double_rebot](https://twitter.com/double_rebot)</h1></center>\n<center><h3>2018-10-31 12:13:37</h3></center>\n\n\nScratch: I forgot to sleep because I was thinking about memes.\n\nNano: If you ever wonder why you have no friends, remember that sentence.\n\n\n<hr>\n\n\n<center><h1> [IMDEA_Nano](https://twitter.com/IMDEA_Nano)</h1></center>\n<center><h3>2018-10-31 12:13:29</h3></center>\n\n\nHave you ever... been five minutes in the life of a molecular shuttle? @IMDEA_nano scientists follow a single molec… https://t.co/V0QOSLAQC2\n\n\n<hr>\n\n\n<center>![](http://geekfence.com/wp-content/uploads/2017/05/bitcoin.jpg)</center>\n",
#      'json_metadata': '{"tags": ["video"]}',
#      'parent_author': '',
#      'parent_permlink': 'video',
#      'permlink': 'what-people-thinks-about-nano-31-october-2018',
#      'title': 'What people thinks about Nano\n31 October 2018'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-31T12:15:15',
#    'trx_id': '17dd6e393fca46c055ed1504f78ae782fa2262d0',
#    'trx_in_block': 25,
#    'virtual_op': 0}],
#  [63359,
#   {'block': 27289349,
#    'op': ['transfer',
#     {'amount': '0.300 STEEM',
#      'from': 'misrori',
#      'memo': 'https://steemit.com/video/@misrori/what-people-thinks-about-nano-31-october-2018',
#      'to': 'postdoctor'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-31T12:15:27',
#    'trx_id': '7944c705655fad6ffcf433ad42d02c7c9f20f8f1',
#    'trx_in_block': 42,
#    'virtual_op': 0}],
#  [63360,
#   {'block': 27289368,
#    'op': ['comment',
#     {'author': 'badcontent',
#      'body': '**This user is on the @buildawhale blacklist for one or more of the following reasons:**\n\n* Spam\n* Plagiarism\n* Scam or Fraud\n\n',
#      'json_metadata': '',
#      'parent_author': 'misrori',
#      'parent_permlink': 'what-people-thinks-about-nano-31-october-2018',
#      'permlink': 're-what-people-thinks-about-nano-31-october-2018-20181031t121624',
#      'title': ''}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-31T12:16:24',
#    'trx_id': '3f6c575e7cca881f785a54903ed07573faa0608e',
#    'trx_in_block': 24,
#    'virtual_op': 0}],
#  [63361,
#   {'block': 27289456,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-nano-31-october-2018',
#      'voter': 'beco132',
#      'weight': 170}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-31T12:20:48',
#    'trx_id': '983325468739ffa22ac005210f9cbd396e3e8024',
#    'trx_in_block': 3,
#    'virtual_op': 0}],
#  [63362,
#   {'block': 27289546,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-nano-31-october-2018',
#      'voter': 'fooart',
#      'weight': 10000}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-31T12:25:18',
#    'trx_id': 'cd82276fe2d56e13d4670ee5d53eaebd2e7f5f0a',
#    'trx_in_block': 0,
#    'virtual_op': 0}],
#  [63363,
#   {'block': 27289643,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-nano-31-october-2018',
#      'voter': 'hr1',
#      'weight': 8}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-31T12:30:12',
#    'trx_id': '25909e01a67ec4d1f0e1590a9f65757b072b33d9',
#    'trx_in_block': 44,
#    'virtual_op': 0}],
#  [63364,
#   {'block': 27290229,
#    'op': ['transfer',
#     {'amount': '0.019 STEEM',
#      'from': 'edensgarden',
#      'memo': 'Round Earnings - 0.019 STEEM | Thank you!',
#      'to': 'misrori'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-31T12:59:30',
#    'trx_id': 'c1e74fb5386c159a96fa66d6ad2b48959af3f834',
#    'trx_in_block': 5,
#    'virtual_op': 0}],
#  [63365,
#   {'block': 27290230,
#    'op': ['transfer',
#     {'amount': '0.019 SBD',
#      'from': 'edensgarden',
#      'memo': 'Round Earnings - 0.019 SBD | Thank you!',
#      'to': 'misrori'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-31T12:59:33',
#    'trx_id': '303ba0d291155b9ce1db2ac7cac66ed1edc5e263',
#    'trx_in_block': 43,
#    'virtual_op': 0}],
#  [63366,
#   {'block': 27290543,
#    'op': ['author_reward',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-monacoin-24-october-2018',
#      'sbd_payout': '0.049 SBD',
#      'steem_payout': '0.000 STEEM',
#      'vesting_payout': '129.079900 VESTS'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-31T13:15:15',
#    'trx_id': '0000000000000000000000000000000000000000',
#    'trx_in_block': 4294967295,
#    'virtual_op': 56}],
#  [63367,
#   {'block': 27290544,
#    'op': ['comment',
#     {'author': 'misrori',
#      'body': '<center><h1> Here you can see the latest 10 twitts about Loopring</h1></center>\n\n\n\n\n<center><h1> [AltcoinNewsfeed](https://twitter.com/AltcoinNewsfeed)</h1></center>\n<center><h3>2018-10-31 11:53:29</h3></center>\n\n\n$LRC Loopring Announces New Airdrop Event #Loopring https://t.co/SH3cILm44m\n\n\n<hr>\n\n\n<center><h1> [coinsentapp](https://twitter.com/coinsentapp)</h1></center>\n<center><h3>2018-10-31 10:27:31</h3></center>\n\n\n@AgnosCrypto @Loopring_king @Superpokemonus @_dev_random_ @HopeStillFlies Great new app! - https://t.co/5GNcbxjMWa… https://t.co/mGbUvuVCM7\n\n\n<hr>\n\n\n<center><h1> [CryptoSigStat](https://twitter.com/CryptoSigStat)</h1></center>\n<center><h3>2018-10-31 10:12:52</h3></center>\n\n\n"Top Running Cryptocurrencies October 31st, 2018"\n\nhttps://t.co/Mr6rNQ9f2L\n\n#Bitcoin #BTC #Chainlink… https://t.co/xtq1ijcEna\n\n\n<hr>\n\n\n<center><h1> [misskhan](https://twitter.com/misskhan)</h1></center>\n<center><h3>2018-10-31 08:47:09</h3></center>\n\n\nRT @coinbureau: Loopring is building a DEX protocol that will facilitate decentralised trading across various exchanges. We take an in-dept…\n\n\n<hr>\n\n\n<center><h1> [coinbureau](https://twitter.com/coinbureau)</h1></center>\n<center><h3>2018-10-31 08:30:02</h3></center>\n\n\nLoopring is building a DEX protocol that will facilitate decentralised trading across various exchanges. We take an… https://t.co/y3zQ0syQX2\n\n\n<hr>\n\n\n<center><h1> [CoinWatcherBot](https://twitter.com/CoinWatcherBot)</h1></center>\n<center><h3>2018-10-31 07:00:14</h3></center>\n\n\nBest returns (24h):\n1. @dentacoin +11.9% $DCN\n2. Chainlink +7.5% $LINK\n3. Loopring +4.7% $LRC\n#blockchain #altcoins https://t.co/wsgCaiAQ19\n\n\n<hr>\n\n\n<center><h1> [Tibor__](https://twitter.com/Tibor__)</h1></center>\n<center><h3>2018-10-31 03:42:07</h3></center>\n\n\n@CryptoGainz1 Check out loopring\n\n\n<hr>\n\n\n<center><h1> [jfromsep](https://twitter.com/jfromsep)</h1></center>\n<center><h3>2018-10-30 23:12:06</h3></center>\n\n\nLoopring team will attend both  #Ethereum DevCon4 in Prague and  first Hong Kong #fintech week! Great news will be… https://t.co/0gl8etqH44\n\n\n<hr>\n\n\n<center><h1> [noticiabitcoin1](https://twitter.com/noticiabitcoin1)</h1></center>\n<center><h3>2018-10-30 16:09:58</h3></center>\n\n\nRT @loopringorg: Win over 500,000 LRC tokens from Bug and Optimization Bounty for Smart Contracts 2.0 \n#devs #smartcontracts #loopring #dex…\n\n\n<hr>\n\n\n<center><h1> [HaiUndCo](https://twitter.com/HaiUndCo)</h1></center>\n<center><h3>2018-10-30 12:58:54</h3></center>\n\n\nRT @oddgems: Some ultra lowcap projects actually working -\n$EXP #expanse 2.8m marketcap\n$BBO #bigbom 589k\n$WEB #webchain 397k\n$ELLA #ellais…\n\n\n<hr>\n\n\n<center>![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTld2NiTa_oIxsC6o9ZdYf8hGrhZOJd5fLPzkzglzBEHhpl7B-0)</center>\n',
#      'json_metadata': '{"tags": ["youtube"]}',
#      'parent_author': '',
#      'parent_permlink': 'youtube',
#      'permlink': 'what-people-thinks-about-loopring-31-october-2018',
#      'title': 'What people thinks about Loopring\n31 October 2018'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-31T13:15:15',
#    'trx_id': 'f5e8acb9bf66254fe67ddf1a7e03c185ed1ed2e8',
#    'trx_in_block': 14,
#    'virtual_op': 0}],
#  [63368,
#   {'block': 27290548,
#    'op': ['transfer',
#     {'amount': '0.300 STEEM',
#      'from': 'misrori',
#      'memo': 'https://steemit.com/youtube/@misrori/what-people-thinks-about-loopring-31-october-2018',
#      'to': 'postdoctor'}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-31T13:15:27',
#    'trx_id': 'e2a17b9d5698b971a878805ace2f6bd6d99cca99',
#    'trx_in_block': 18,
#    'virtual_op': 0}],
#  [63369,
#   {'block': 27290567,
#    'op': ['comment',
#     {'author': 'badcontent',
#      'body': '**This user is on the @buildawhale blacklist for one or more of the following reasons:**\n\n* Spam\n* Plagiarism\n* Scam or Fraud\n\n',
#      'json_metadata': '',
#      'parent_author': 'misrori',
#      'parent_permlink': 'what-people-thinks-about-loopring-31-october-2018',
#      'permlink': 're-what-people-thinks-about-loopring-31-october-2018-20181031t131624',
#      'title': ''}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-31T13:16:24',
#    'trx_id': '4644514bd64c7ff4c629e38eda4c372de0d8cbde',
#    'trx_in_block': 21,
#    'virtual_op': 0}],
#  [63370,
#   {'block': 27290780,
#    'op': ['vote',
#     {'author': 'misrori',
#      'permlink': 'what-people-thinks-about-loopring-31-october-2018',
#      'voter': 'beco132',
#      'weight': 170}],
#    'op_in_trx': 0,
#    'timestamp': '2018-10-31T13:27:03',
#    'trx_id': 'af3b0e522c9f8400df747dffce94c27e033fc273',
#    'trx_in_block': 24,
#    'virtual_op': 0}]]
